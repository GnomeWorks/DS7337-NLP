# %% [markdown]
# # Get the data
# Import and take a look.  Note that the Sentiment is column 5 and tweet is column 15

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("./Sentiment.csv")

# %%
data.head()
# Out:
#    id               candidate  candidate_confidence relevant_yn  \
# 0   1  No candidate mentioned                   1.0         yes
# 1   2            Scott Walker                   1.0         yes
# 2   3  No candidate mentioned                   1.0         yes
# 3   4  No candidate mentioned                   1.0         yes
# 4   5            Donald Trump                   1.0         yes
#
#    relevant_yn_confidence sentiment  sentiment_confidence     subject_matter  \
# 0                     1.0   Neutral                0.6578  None of the above
# 1                     1.0  Positive                0.6333  None of the above
# 2                     1.0   Neutral                0.6629  None of the above
# 3                     1.0  Positive                1.0000  None of the above
# 4                     1.0  Positive                0.7045  None of the above
#
#    subject_matter_confidence candidate_gold  ... relevant_yn_gold  \
# 0                     1.0000            NaN  ...              NaN
# 1                     1.0000            NaN  ...              NaN
# 2                     0.6629            NaN  ...              NaN
# 3                     0.7039            NaN  ...              NaN
# 4                     1.0000            NaN  ...              NaN
#
#   retweet_count  sentiment_gold subject_matter_gold  \
# 0             5             NaN                 NaN
# 1            26             NaN                 NaN
# 2            27             NaN                 NaN
# 3           138             NaN                 NaN
# 4           156             NaN                 NaN
#
#                                                 text tweet_coord  \
# 0  RT @NancyLeeGrahn: How did everyone feel about...         NaN
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...         NaN
# 2  RT @TJMShow: No mention of Tamir Rice and the ...         NaN
# 3  RT @RobGeorge: That Carly Fiorina is trending ...         NaN
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...         NaN
#
#                tweet_created            tweet_id  tweet_location  \
# 0  2015-08-07 09:54:46 -0700  629697200650592256             NaN
# 1  2015-08-07 09:54:46 -0700  629697199560069120             NaN
# 2  2015-08-07 09:54:46 -0700  629697199312482304             NaN
# 3  2015-08-07 09:54:45 -0700  629697197118861312           Texas
# 4  2015-08-07 09:54:45 -0700  629697196967903232             NaN
#
#                 user_timezone
# 0                       Quito
# 1                         NaN
# 2                         NaN
# 3  Central Time (US & Canada)
# 4                     Arizona
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Build a map
# Ok i cheated.  I used this handy dandy function and the Counter() method from Python.
#
# If you are not familiar with collections, check them out.  Counter() and defaultdict() are super handy for general data wrangling.

# %%
import collections
def build_dataset(words):
    count = collections.Counter(words).most_common()
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dictionary

# %% [markdown]
# ### Split
# Need test and train sets.  Split by 75%
#
# Mean professor also forgot to mention that there is a 3rd class.  We can either train for it or drop it.

# %%
n=int(np.floor(data.shape[0]*0.75))

# %%
train = data[0:n]
test = data[n:]
train = train[train['sentiment']!='Neutral']
test = test[test['sentiment']!='Neutral']

# %% [markdown]
# ### Build a word list.
#
# Iterate through the entire data set, split the tweets into tokens and append it to one giant list.
# This is a bit of a 'brute force' method, but it works.
#
# Alternatively, one could build a map directly from here by using the folling psuedo code
# ```
# word_map=dict()
# for i in data['text']:
#     words = i.split()
#     for i in words:
#         if word not in word_map:  # this is psuedo code
#             add it!               # so is this
#         else:
#             pass
# ```
#
# I'll stick with my big word list cause it works.
#
# Note their are also faster ways to interate through a dataframe.

# %%
word_list=[]
for i in data['text']:
    word_list = word_list + i.split()

# %%
len(word_list)
# Out:
# 235029

# %% [markdown]
# Now I build my maps.  Since I was uncool and ganked my code from someone else, there is a brute force way afterwards

# %%
enc, dec = build_dataset(word_list)

# %%
dec
# Out:
# {0: 'RT',
#  1: 'the',
#  2: '#GOPDebate',
#  3: 'to',
#  4: '#GOPDebates',
#  5: 'of',
#  6: 'a',
#  7: 'is',
#  8: 'and',
#  9: 'I',
#  10: '@RWSurferGirl:',
#  11: 'in',
#  12: '🇺🇸',
#  13: 'for',
#  14: 'on',
#  15: 'you',
#  16: 'that',
#  17: 'Trump',
#  18: 'it',
#  19: 'about',
#  20: 'was',
#  21: '&amp;',
#  22: 'not',
#  23: 'Fox',
#  24: '@realDonaldTrump',
#  25: 'The',
#  26: 'this',
#  27: 'at',
#  28: 'have',
#  29: 'from',
#  30: 'be',
#  31: 'last',
#  32: 'are',
#  33: 'but',
#  34: 'News',
#  35: 'with',
#  36: 'like',
#  37: 'just',
#  38: 'me',
#  39: 'he',
#  40: 'they',
#  41: "don't",
#  42: 'who',
#  43: 'has',
#  44: 'people',
#  45: 'we',
#  46: 'what',
#  47: '@megynkelly',
#  48: 'Jeb',
#  49: 'their',
#  50: 'candidates',
#  51: 'by',
#  52: 'as',
#  53: 'my',
#  54: 'up',
#  55: 'Bush',
#  56: 'would',
#  57: 'all',
#  58: 'think',
#  59: 'You',
#  60: 'out',
#  61: 'how',
#  62: 'get',
#  63: 'will',
#  64: 'GOP',
#  65: 'or',
#  66: 'debate',
#  67: "I'm",
#  68: 'when',
#  69: 'Chris',
#  70: 'his',
#  71: 'should',
#  72: 'if',
#  73: 'one',
#  74: '…',
#  75: 'more',
#  76: 'need',
#  77: '-',
#  78: 'do',
#  79: 'can',
#  80: 'Republican',
#  81: 'your',
#  82: '#GOPdebates',
#  83: 'want',
#  84: 'Donald',
#  85: '#GOPdebate',
#  86: 'him',
#  87: 'It',
#  88: '@FoxNews',
#  89: 'So',
#  90: 'these',
#  91: 'ask',
#  92: 'than',
#  93: 'We',
#  94: 'really',
#  95: 'know',
#  96: 'night',
#  97: 'so',
#  98: 'an',
#  99: 'no',
#  100: 'did',
#  101: 'only',
#  102: 'Cruz',
#  103: 'our',
#  104: 'very',
#  105: 'were',
#  106: 'This',
#  107: 'FOX',
#  108: 'them',
#  109: 'Wallace',
#  110: 'watching',
#  111: "doesn't",
#  112: 'candidate',
#  113: 'God',
#  114: 'after',
#  115: 'next',
#  116: 'see',
#  117: 'Is',
#  118: 'other',
#  119: 'said',
#  120: 'hear',
#  121: "night's",
#  122: "didn't",
#  123: 'trying',
#  124: 'time',
#  125: 'Why',
#  126: 'anyone',
#  127: 'does',
#  128: 'American',
#  129: '#GOPDebate.',
#  130: 'A',
#  131: 'any',
#  132: 'got',
#  133: '"Fair',
#  134: 'Balanced"',
#  135: 'most',
#  136: 'where',
#  137: 'Carson',
#  138: '#GopDebates',
#  139: '#tcot',
#  140: 'President',
#  141: '@monaeltahawy:',
#  142: 'If',
#  143: 'set',
#  144: 'take',
#  145: '#gopdebate',
#  146: 'via',
#  147: 'say',
#  148: 'it.',
#  149: 'Ben',
#  150: '#G…',
#  151: "it's",
#  152: 'else',
#  153: 'had',
#  154: "you're",
#  155: 'never',
#  156: 'going',
#  157: 'reminds',
#  158: '@SupermanHotMale:',
#  159: 'debate.',
#  160: 'Huckabee',
#  161: 'Rubio,',
#  162: 'My',
#  163: 'How',
#  164: 'doing',
#  165: 'talk',
#  166: 'attack',
#  167: 'right',
#  168: 'now',
#  169: 'during',
#  170: 'What',
#  171: '#GOPDebat…',
#  172: 'rid',
#  173: 'gets',
#  174: 'elevator',
#  175: 'music.',
#  176: 'listen.',
#  177: "It's",
#  178: "can't",
#  179: 'obviously',
#  180: 'watch',
#  181: 'influence',
#  182: 'am',
#  183: 'her',
#  184: 'Megyn',
#  185: 'questions',
#  186: 'make',
#  187: '#Trump',
#  188: 'pick',
#  189: 'makeup',
#  190: 'Hillary',
#  191: 'comes',
#  192: 'candidates.',
#  193: 'stage',
#  194: 'field.',
#  195: 'United',
#  196: 'real',
#  197: 'money',
#  198: 'great',
#  199: 'Rand',
#  200: 'talking',
#  201: '#TedCruz',
#  202: 'tell',
#  203: 'being',
#  204: 'together',
#  205: 'Debate.',
#  206: 'each',
#  207: 'military',
#  208: 'many',
#  209: 'States',
#  210: 'won',
#  211: 'job,',
#  212: 'Who',
#  213: 'good',
#  214: 'And',
#  215: 'Not',
#  216: 'questions.',
#  217: 'disappointing',
#  218: 'Thanks',
#  219: 'conducting',
#  220: '#GOPDebate:',
#  221: 'band',
#  222: 'He',
#  223: 'expose',
#  224: 'question',
#  225: 'No',
#  226: 'even',
#  227: 'night.',
#  228: 'over',
#  229: 'America',
#  230: 'women',
#  231: 'says',
#  232: 'men',
#  233: 'Ted',
#  234: '@CarlyFiorina',
#  235: 'support',
#  236: 'punch',
#  237: 'best',
#  238: 'some',
#  239: 'because',
#  240: '#GOPDebate…',
#  241: "I'd",
#  242: 'face?',
#  243: 'Paul',
#  244: 'much',
#  245: 'speaking.',
#  246: 'Rubio',
#  247: 'long',
#  248: 'into',
#  249: 'stoping',
#  250: '#…',
#  251: 'bring',
#  252: '#gopdebates',
#  253: 'better',
#  254: '#GOPDebate,',
#  255: 'As',
#  256: 'picking',
#  257: 'softball',
#  258: 'They',
#  259: 'been',
#  260: '2',
#  261: 'win',
#  262: 'Christie',
#  263: 'why',
#  264: 'there',
#  265: 'cherry',
#  266: '10',
#  267: 'question.',
#  268: 'Did',
#  269: 'finances',
#  270: 'from?',
#  271: 'first',
#  272: '#GOP',
#  273: "'s",
#  274: 'politicans',
#  275: "won't",
#  276: 'Kelly',
#  277: 'Kasich',
#  278: 'mean',
#  279: 'vote',
#  280: '#DonaldTrump',
#  281: '"The',
#  282: 'she',
#  283: 'someone',
#  284: 'big',
#  285: 'still',
#  286: 'Obama',
#  287: 'adult',
#  288: 'break',
#  289: 'Walker',
#  290: 'made',
#  291: '"I',
#  292: 'up?',
#  293: 'us',
#  294: 'off',
#  295: 'posed',
#  296: '#FoxNews',
#  297: 'kill',
#  298: 'winner',
#  299: 'pictures.should',
#  300: 'Just',
#  301: 'News,',
#  302: 'go',
#  303: 'seem',
#  304: 'could',
#  305: "he's",
#  306: 'face',
#  307: '@HillaryClinton',
#  308: 'always',
#  309: '#KKKorGOP',
#  310: 'every',
#  311: 'given',
#  312: '@Lrihendry:',
#  313: 'Scott',
#  314: 'political',
#  315: 'After',
#  316: 'word',
#  317: 'job',
#  318: 'ratings.',
#  319: 'rights',
#  320: 'Twitter',
#  321: 'candidates,',
#  322: 'looking',
#  323: 'answer',
#  324: 'plan',
#  325: 'raising',
#  326: '#GOPD…',
#  327: 'That',
#  328: 'thing',
#  329: 'Marco',
#  330: 'control',
#  331: '@GovChristie',
#  332: '@goldietaylor:',
#  333: 'Carly',
#  334: 'Debate',
#  335: '#GOPDebates.',
#  336: 'In',
#  337: 'country',
#  338: 'sure',
#  339: 'tonight.',
#  340: 'Presidential',
#  341: 'Ask',
#  342: 'Last',
#  343: 'those',
#  344: 'way',
#  345: 'actually',
#  346: 'When',
#  347: 'Fiorina',
#  348: 'thinks',
#  349: '#BlackLivesMatter',
#  350: 'forward',
#  351: 'purpose',
#  352: '@tedcruz',
#  353: 'back',
#  354: "I've",
#  355: 'give',
#  356: 'Look',
#  357: 'One',
#  358: 'hands.',
#  359: '#GOPDebate?',
#  360: 'Oh',
#  361: 'ME',
#  362: 'then',
#  363: 'here',
#  364: 'same',
#  365: 'NOT',
#  366: 'debate,',
#  367: 'presidential',
#  368: 'man',
#  369: 'debates',
#  370: 'love',
#  371: 'said,',
#  372: 'moderators',
#  373: '?',
#  374: 'Party',
#  375: 'leader',
#  376: 'legitimate',
#  377: 'do.',
#  378: 'truth,',
#  379: 'Dear',
#  380: 'call',
#  381: 'nails',
#  382: 'look',
#  383: 'watched',
#  384: 'admit',
#  385: '@ericstonestreet:',
#  386: 'Cam',
#  387: '@RealBenCarson',
#  388: 'asked',
#  389: '@larryelder:',
#  390: "Wallace's",
#  391: '1',
#  392: 'all.',
#  393: 'These',
#  394: 'Hey',
#  395: 'Can',
#  396: 'show',
#  397: 'thought',
#  398: 'wants',
#  399: 'lead',
#  400: '@marcorubio',
#  401: 'Trump,',
#  402: 'ever',
#  403: 'new',
#  404: 'saying',
#  405: 'President,',
#  406: 'Republicans',
#  407: 'John',
#  408: 'party',
#  409: 'down',
#  410: 'To',
#  411: '@RandPaul',
#  412: 'nine',
#  413: '"Megyn,',
#  414: '#Trump2016',
#  415: 'nomination."',
#  416: '@BettyFckinWhite:',
#  417: 'too',
#  418: 'which',
#  419: '.',
#  420: 'getting',
#  421: 'But',
#  422: "Trump's",
#  423: 'running',
#  424: 'needs',
#  425: 'seen',
#  426: 'frontrunner',
#  427: "women's",
#  428: 'little',
#  429: 'let',
#  430: 'against',
#  431: 'making',
#  432: 'tonight',
#  433: 'fight',
#  434: 'THE',
#  435: 'enough',
#  436: 'Cruz,',
#  437: '@GOP',
#  438: 'things',
#  439: 'order',
#  440: 'black',
#  441: 'learned',
#  442: 'Clinton',
#  443: 'everyone',
#  444: 'guys',
#  445: 'woman',
#  446: 'believe',
#  447: 'Enjoyed',
#  448: '#DemocraticDebates',
#  449: 'next.',
#  450: 'illegal',
#  451: 'care',
#  452: 'All',
#  453: 'Democrats',
#  454: '=',
#  455: 'another',
#  456: 'nothing',
#  457: 'makes',
#  458: '#FoxDebate',
#  459: 'Trump:',
#  460: 'speak.',
#  461: 'it,',
#  462: 'bad',
#  463: 'discussing',
#  464: 'white',
#  465: 'looks',
#  466: 'feel',
#  467: '@JebBush',
#  468: 'keep',
#  469: 'closing',
#  470: 'TV',
#  471: '2016',
#  472: 'u',
#  473: 'media',
#  474: 'Huckabee.',
#  475: 'double-digit',
#  476: '@GovMikeHuckabee',
#  477: 'stop',
#  478: 'calling',
#  479: 'Dr.',
#  480: '@DonnieWahlberg:',
#  481: "That's",
#  482: 'news',
#  483: '@jamiaw:',
#  484: 'things"-Mike',
#  485: '--',
#  486: 'run',
#  487: 'before',
#  488: 'person',
#  489: 'bodies',
#  490: 'came',
#  491: 'hard',
#  492: 'fact',
#  493: 'Watching',
#  494: 'Reagan',
#  495: "wasn't",
#  496: 'night?',
#  497: 'up.',
#  498: 'favorite',
#  499: 'help',
#  500: 'US',
#  501: 'lot',
#  502: '@SalMasekela:',
#  503: 'day',
#  504: 'debate?',
#  505: 'put',
#  506: 'She',
#  507: '!',
#  508: 'hell',
#  509: 'night,',
#  510: "I'll",
#  511: 'THIS',
#  512: 'part',
#  513: 'Now',
#  514: 'president.',
#  515: 'own',
#  516: 'Has',
#  517: 'away',
#  518: 'brought',
#  519: 'problem',
#  520: '5',
#  521: 'Carson,',
#  522: '4',
#  523: 'biggest',
#  524: 'Mike',
#  525: 'live',
#  526: '@JohnKasich',
#  527: 'civil',
#  528: 'mention',
#  529: 'important',
#  530: '#p2',
#  531: 'Do',
#  532: 'question?',
#  533: 'social',
#  534: 'clear',
#  535: '...',
#  536: 'guy',
#  537: "that's",
#  538: 'Tonight',
#  539: 'http://t.co/Zy12bdUkx9',
#  540: 'hate',
#  541: '@BretBaier',
#  542: 'gave',
#  543: 'LOL',
#  544: 'issues',
#  545: 'seems',
#  546: 'come',
#  547: 'deserve',
#  548: 'whole',
#  549: 'today',
#  550: 'two',
#  551: 'voting',
#  552: '@ScottWalker',
#  553: 'may',
#  554: "isn't",
#  555: 'Americans',
#  556: 'gay',
#  557: 'now.',
#  558: 'From',
#  559: 'start',
#  560: 'audience',
#  561: 'went',
#  562: 'took',
#  563: 'world',
#  564: 'called',
#  565: 'years',
#  566: 'There',
#  567: 'misogyny',
#  568: 'process',
#  569: 'while',
#  570: 'Trump.',
#  571: 'Iran',
#  572: 'anything',
#  573: 'pretty',
#  574: 'terrorism.',
#  575: 'Christian',
#  576: 'w/',
#  577: '@ChrisChristie',
#  578: 'under',
#  579: "they're",
#  580: '3',
#  581: 'president',
#  582: 'climate',
#  583: 'ALL',
#  584: '#DebateWithBernie',
#  585: 'single',
#  586: 'On',
#  587: '#MegynKelly',
#  588: '#GOPdebate:',
#  589: 'used',
#  590: 'code',
#  591: 'woman.',
#  592: 'time.',
#  593: 'voters',
#  594: 'campaign',
#  595: 'something',
#  596: 'find',
#  597: 'must',
#  598: 'having',
#  599: 'him.',
#  600: 'answers',
#  601: 'Good',
#  602: 'happened.',
#  603: 'For',
#  604: 'focus',
#  605: 'told',
#  606: '@YouTube',
#  607: "Don't",
#  608: 'remove',
#  609: 'green',
#  610: 'heard',
#  611: 'performance',
#  612: 'abortion',
#  613: 'IS',
#  614: 'point',
#  615: 'tax',
#  616: 'fucking',
#  617: 'http://t.co/AuhlNZa3Ww',
#  618: 'apple',
#  619: 'martini',
#  620: '@mozgovaya:',
#  621: 'First',
#  622: 'between',
#  623: "Here's",
#  624: 'saw',
#  625: 'i',
#  626: 'work',
#  627: 'direct',
#  628: '#GOPDeb…',
#  629: 'TO',
#  630: 'life',
#  631: 'most.',
#  632: 'ratings',
#  633: 'Was',
#  634: 'race',
#  635: 'http://t.c…',
#  636: 'At',
#  637: 'bunch',
#  638: 'both',
#  639: 'U.S.',
#  640: 'w',
#  641: 'send',
#  642: 'fun',
#  643: 'hugged',
#  644: 'Planned',
#  645: 'far',
#  646: 'gonna',
#  647: '1st',
#  648: 'http:/…',
#  649: 'moment',
#  650: 'By',
#  651: 'shit',
#  652: 'Thank',
#  653: "Can't",
#  654: '#ccot',
#  655: 'well',
#  656: '"social',
#  657: 'stage.',
#  658: 'primaries.',
#  659: 'issues"',
#  660: 'full',
#  661: 'His',
#  662: 'Great',
#  663: 'Of',
#  664: 'received',
#  665: "Who's",
#  666: 'Immigration',
#  667: 'without',
#  668: 'Bernie',
#  669: 'less',
#  670: '#GOP…',
#  671: 'YOU',
#  672: 'hair',
#  673: '@',
#  674: '"We',
#  675: 'state',
#  676: 'Well',
#  677: '@pattonoswalt:',
#  678: 'http…',
#  679: 'change',
#  680: "couldn't",
#  681: '.@realDonaldTrump',
#  682: 'missed',
#  683: 'Women',
#  684: 'Are',
#  685: 'tough',
#  686: 'mentioned',
#  687: 'killing',
#  688: '#GO…',
#  689: 'end',
#  690: 'realize',
#  691: 'reality',
#  692: 'trump',
#  693: 'its',
#  694: 'talks',
#  695: 'Cancel',
#  696: 'Best',
#  697: 'Walker,',
#  698: '@TheBaxterBean:',
#  699: 'true',
#  700: 'Rosie',
#  701: 'wait',
#  702: 'respect',
#  703: 'giving',
#  704: 'left',
#  705: 'group',
#  706: '@SenTedCruz',
#  707: 'thoughts',
#  708: 'become',
#  709: 'also',
#  710: 'nobody',
#  711: 'nights',
#  712: 'Does',
#  713: 'Hold',
#  714: 'sexuality',
#  715: 'line',
#  716: 'http://t…',
#  717: 'primary',
#  718: '#GOPDe…',
#  719: 'times',
#  720: 'until',
#  721: 'Your',
#  722: '|',
#  723: 'play',
#  724: 'Ronald',
#  725: 'GO',
#  726: 'asking',
#  727: 'boy:',
#  728: 'tight,',
#  729: 'TwitterLand',
#  730: 'comments',
#  731: 'Paul,',
#  732: '#CruzCrew',
#  733: 'htt…',
#  734: 'might',
#  735: 'wonder',
#  736: '@FrankLuntz',
#  737: 'Mexican',
#  738: 'women.',
#  739: '#KellyFile',
#  740: 'war',
#  741: 'deal',
#  742: 'entertaining',
#  743: 'Will',
#  744: 'politicians',
#  745: "tonight's",
#  746: 'pissed',
#  747: 'showed',
#  748: 'perfect',
#  749: '-I',
#  750: 'anointed',
#  751: 'calls',
#  752: 'http://…',
#  753: 'http:…',
#  754: 'me.',
#  755: 'Go',
#  756: '#RandPaul',
#  757: 'totally',
#  758: '8',
#  759: 'wins',
#  760: 'Florida',
#  761: 'gone',
#  762: 'Wasserman-Schultz',
#  763: 'words',
#  764: 'hope',
#  765: 'alien',
#  766: 'immigration',
#  767: "aren't",
#  768: 'With',
#  769: '#morningjoe',
#  770: '@kwrcrow:',
#  771: '-Can',
#  772: '-So,',
#  773: 'no?',
#  774: 'ISIS',
#  775: 'Social',
#  776: 'name',
#  777: 'ht…',
#  778: 'people.',
#  779: 'pay',
#  780: 'stand',
#  781: '#Kasich',
#  782: 'half',
#  783: 'issue',
#  784: 'everything',
#  785: 'gun',
#  786: 'through',
#  787: 'kind',
#  788: 'around',
#  789: 'U',
#  790: 'fair',
#  791: 'kids',
#  792: 'few',
#  793: 'Farrakhan',
#  794: 'Bor...',
#  795: 'old',
#  796: 'coming',
#  797: 'New',
#  798: 'minutes',
#  799: '#GOPDeba…',
#  800: 'tonight,',
#  801: 'once',
#  802: 'Anyone',
#  803: '#TCOT',
#  804: 'damn',
#  805: 'right,',
#  806: '#FOXNEWSDEBATE',
#  807: 'wondering',
#  808: 'immigration,',
#  809: '#GOPDebates?',
#  810: '#CantTrustABush',
#  811: 'http://t.…',
#  812: 'class',
#  813: 'destroy',
#  814: 'police',
#  815: 'White',
#  816: '#GOPClownCar',
#  817: 'record',
#  818: 'place',
#  819: 'probably',
#  820: 'lost',
#  821: '#Carly2016',
#  822: 'https://t.co/lkLfFN2LFy',
#  823: 'winners',
#  824: 'past',
#  825: "Let's",
#  826: 'Carson:',
#  827: 'So,',
#  828: 'politically',
#  829: 'Sanders',
#  830: 'ass',
#  831: 'DC',
#  832: 'person.',
#  833: 'Debates.',
#  834: 'morning',
#  835: 'done',
#  836: "You're",
#  837: 'Jon',
#  838: 'wish',
#  839: 'instead',
#  840: 'OF',
#  841: 'himself',
#  842: 'agree',
#  843: 'speak',
#  844: 'please',
#  845: 'taking',
#  846: 'head',
#  847: 'top',
#  848: 'Two',
#  849: 'Back',
#  850: 'facing',
#  851: 'https://t…',
#  852: '#GOPDebates,',
#  853: 'loved',
#  854: 'Bush,',
#  855: 'More',
#  856: ':',
#  857: 'response',
#  858: '#Fiorina',
#  859: 'election',
#  860: '@DWStweets',
#  861: 'vs',
#  862: "He's",
#  863: 'Please',
#  864: '#JonVoyage',
#  865: 'themselves',
#  866: "we're",
#  867: 'Then',
#  868: 'Very',
#  869: 'pledge',
#  870: 'Only',
#  871: 'use',
#  872: 'friends',
#  873: 'spent',
#  874: 'Walker:',
#  875: 'republican',
#  876: '#FF',
#  877: 'read',
#  878: 'Our',
#  879: 'commercial',
#  880: 'hangover',
#  881: 'laws',
#  882: '@PuestoLoco:',
#  883: 'headed',
#  884: 'TED!!',
#  885: 'http://t.co/8S67pz8a4A',
#  886: 'speaking',
#  887: 'Democrat',
#  888: 'refuse',
#  889: '#WakeUpAmerica',
#  890: '2nd',
#  891: 'points',
#  892: 'post',
#  893: 'check',
#  894: 'again',
#  895: 'office',
#  896: 'statement',
#  897: 'miss',
#  898: 'down.',
#  899: 'rather',
#  900: 'Most',
#  901: 'marriage',
#  902: 'analysis',
#  903: 'Kelly,',
#  904: 'knows',
#  905: 'Let',
#  906: 'sober',
#  907: 'untill',
#  908: 'God?!',
#  909: 'hopefuls?!',
#  910: 'America?!',
#  911: 'Brotherhood',
#  912: '@marymauldin:',
#  913: 'http://t.co…',
#  914: 'tweet',
#  915: 'government',
#  916: 'Black',
#  917: 'impressed',
#  918: 'playing',
#  919: 'night:',
#  920: 'Even',
#  921: 'conservative',
#  922: 'Koch',
#  923: "let's",
#  924: 'least',
#  925: 'People',
#  926: '#IranDeal',
#  927: '"I\'m',
#  928: 'already',
#  929: 'Future',
#  930: 'interesting',
#  931: "Cruz's",
#  932: 'maybe',
#  933: 'sense',
#  934: 'unfathomable',
#  935: 'postmortem',
#  936: '#SURREAL',
#  937: 'NO',
#  938: 'AND',
#  939: 'moments',
#  940: 'Status',
#  941: '#CarlyFiorina',
#  942: 'that.',
#  943: 'Maybe',
#  944: 'us.',
#  945: 'this.',
#  946: "there's",
#  947: '#BenCarson',
#  948: 'year',
#  949: 'poor',
#  950: 'wanted',
#  951: 'changed',
#  952: 'Closing',
#  953: 'killed',
#  954: 'Facebook',
#  955: '#UniteBlue',
#  956: 'establishment',
#  957: 'Check',
#  958: 'Love',
#  959: 'racism',
#  960: '#TedCruz2016',
#  961: 'attacks',
#  962: '#GOPtbt',
#  963: 'personal',
#  964: 'takes',
#  965: 'loser',
#  966: 'absolutely',
#  967: 'men,',
#  968: 'business',
#  969: 'thinking',
#  970: '#GOPDEBATES',
#  971: '#toot',
#  972: '@Desdemona4U:',
#  973: '@LibertyU',
#  974: '#Walker16',
#  975: 'An',
#  976: 'cut',
#  977: 'almost',
#  978: 'crazy',
#  979: 'shut',
#  980: 'future',
#  981: '#tlot',
#  982: 'politics',
#  983: '@foxnews',
#  984: 'either',
#  985: 'liberal',
#  986: "we'll",
#  987: 'yet',
#  988: '@CNN',
#  989: 'proud',
#  990: 'out.',
#  991: 'Some',
#  992: 'Megan',
#  993: 'candidate.',
#  994: 'free',
#  995: 'knew',
#  996: "shouldn't",
#  997: '#trump',
#  998: 'China',
#  999: 'fuck',
#  ...}

# %%
enc
# Out:
# {'RT': 0,
#  'the': 1,
#  '#GOPDebate': 2,
#  'to': 3,
#  '#GOPDebates': 4,
#  'of': 5,
#  'a': 6,
#  'is': 7,
#  'and': 8,
#  'I': 9,
#  '@RWSurferGirl:': 10,
#  'in': 11,
#  '🇺🇸': 12,
#  'for': 13,
#  'on': 14,
#  'you': 15,
#  'that': 16,
#  'Trump': 17,
#  'it': 18,
#  'about': 19,
#  'was': 20,
#  '&amp;': 21,
#  'not': 22,
#  'Fox': 23,
#  '@realDonaldTrump': 24,
#  'The': 25,
#  'this': 26,
#  'at': 27,
#  'have': 28,
#  'from': 29,
#  'be': 30,
#  'last': 31,
#  'are': 32,
#  'but': 33,
#  'News': 34,
#  'with': 35,
#  'like': 36,
#  'just': 37,
#  'me': 38,
#  'he': 39,
#  'they': 40,
#  "don't": 41,
#  'who': 42,
#  'has': 43,
#  'people': 44,
#  'we': 45,
#  'what': 46,
#  '@megynkelly': 47,
#  'Jeb': 48,
#  'their': 49,
#  'candidates': 50,
#  'by': 51,
#  'as': 52,
#  'my': 53,
#  'up': 54,
#  'Bush': 55,
#  'would': 56,
#  'all': 57,
#  'think': 58,
#  'You': 59,
#  'out': 60,
#  'how': 61,
#  'get': 62,
#  'will': 63,
#  'GOP': 64,
#  'or': 65,
#  'debate': 66,
#  "I'm": 67,
#  'when': 68,
#  'Chris': 69,
#  'his': 70,
#  'should': 71,
#  'if': 72,
#  'one': 73,
#  '…': 74,
#  'more': 75,
#  'need': 76,
#  '-': 77,
#  'do': 78,
#  'can': 79,
#  'Republican': 80,
#  'your': 81,
#  '#GOPdebates': 82,
#  'want': 83,
#  'Donald': 84,
#  '#GOPdebate': 85,
#  'him': 86,
#  'It': 87,
#  '@FoxNews': 88,
#  'So': 89,
#  'these': 90,
#  'ask': 91,
#  'than': 92,
#  'We': 93,
#  'really': 94,
#  'know': 95,
#  'night': 96,
#  'so': 97,
#  'an': 98,
#  'no': 99,
#  'did': 100,
#  'only': 101,
#  'Cruz': 102,
#  'our': 103,
#  'very': 104,
#  'were': 105,
#  'This': 106,
#  'FOX': 107,
#  'them': 108,
#  'Wallace': 109,
#  'watching': 110,
#  "doesn't": 111,
#  'candidate': 112,
#  'God': 113,
#  'after': 114,
#  'next': 115,
#  'see': 116,
#  'Is': 117,
#  'other': 118,
#  'said': 119,
#  'hear': 120,
#  "night's": 121,
#  "didn't": 122,
#  'trying': 123,
#  'time': 124,
#  'Why': 125,
#  'anyone': 126,
#  'does': 127,
#  'American': 128,
#  '#GOPDebate.': 129,
#  'A': 130,
#  'any': 131,
#  'got': 132,
#  '"Fair': 133,
#  'Balanced"': 134,
#  'most': 135,
#  'where': 136,
#  'Carson': 137,
#  '#GopDebates': 138,
#  '#tcot': 139,
#  'President': 140,
#  '@monaeltahawy:': 141,
#  'If': 142,
#  'set': 143,
#  'take': 144,
#  '#gopdebate': 145,
#  'via': 146,
#  'say': 147,
#  'it.': 148,
#  'Ben': 149,
#  '#G…': 150,
#  "it's": 151,
#  'else': 152,
#  'had': 153,
#  "you're": 154,
#  'never': 155,
#  'going': 156,
#  'reminds': 157,
#  '@SupermanHotMale:': 158,
#  'debate.': 159,
#  'Huckabee': 160,
#  'Rubio,': 161,
#  'My': 162,
#  'How': 163,
#  'doing': 164,
#  'talk': 165,
#  'attack': 166,
#  'right': 167,
#  'now': 168,
#  'during': 169,
#  'What': 170,
#  '#GOPDebat…': 171,
#  'rid': 172,
#  'gets': 173,
#  'elevator': 174,
#  'music.': 175,
#  'listen.': 176,
#  "It's": 177,
#  "can't": 178,
#  'obviously': 179,
#  'watch': 180,
#  'influence': 181,
#  'am': 182,
#  'her': 183,
#  'Megyn': 184,
#  'questions': 185,
#  'make': 186,
#  '#Trump': 187,
#  'pick': 188,
#  'makeup': 189,
#  'Hillary': 190,
#  'comes': 191,
#  'candidates.': 192,
#  'stage': 193,
#  'field.': 194,
#  'United': 195,
#  'real': 196,
#  'money': 197,
#  'great': 198,
#  'Rand': 199,
#  'talking': 200,
#  '#TedCruz': 201,
#  'tell': 202,
#  'being': 203,
#  'together': 204,
#  'Debate.': 205,
#  'each': 206,
#  'military': 207,
#  'many': 208,
#  'States': 209,
#  'won': 210,
#  'job,': 211,
#  'Who': 212,
#  'good': 213,
#  'And': 214,
#  'Not': 215,
#  'questions.': 216,
#  'disappointing': 217,
#  'Thanks': 218,
#  'conducting': 219,
#  '#GOPDebate:': 220,
#  'band': 221,
#  'He': 222,
#  'expose': 223,
#  'question': 224,
#  'No': 225,
#  'even': 226,
#  'night.': 227,
#  'over': 228,
#  'America': 229,
#  'women': 230,
#  'says': 231,
#  'men': 232,
#  'Ted': 233,
#  '@CarlyFiorina': 234,
#  'support': 235,
#  'punch': 236,
#  'best': 237,
#  'some': 238,
#  'because': 239,
#  '#GOPDebate…': 240,
#  "I'd": 241,
#  'face?': 242,
#  'Paul': 243,
#  'much': 244,
#  'speaking.': 245,
#  'Rubio': 246,
#  'long': 247,
#  'into': 248,
#  'stoping': 249,
#  '#…': 250,
#  'bring': 251,
#  '#gopdebates': 252,
#  'better': 253,
#  '#GOPDebate,': 254,
#  'As': 255,
#  'picking': 256,
#  'softball': 257,
#  'They': 258,
#  'been': 259,
#  '2': 260,
#  'win': 261,
#  'Christie': 262,
#  'why': 263,
#  'there': 264,
#  'cherry': 265,
#  '10': 266,
#  'question.': 267,
#  'Did': 268,
#  'finances': 269,
#  'from?': 270,
#  'first': 271,
#  '#GOP': 272,
#  "'s": 273,
#  'politicans': 274,
#  "won't": 275,
#  'Kelly': 276,
#  'Kasich': 277,
#  'mean': 278,
#  'vote': 279,
#  '#DonaldTrump': 280,
#  '"The': 281,
#  'she': 282,
#  'someone': 283,
#  'big': 284,
#  'still': 285,
#  'Obama': 286,
#  'adult': 287,
#  'break': 288,
#  'Walker': 289,
#  'made': 290,
#  '"I': 291,
#  'up?': 292,
#  'us': 293,
#  'off': 294,
#  'posed': 295,
#  '#FoxNews': 296,
#  'kill': 297,
#  'winner': 298,
#  'pictures.should': 299,
#  'Just': 300,
#  'News,': 301,
#  'go': 302,
#  'seem': 303,
#  'could': 304,
#  "he's": 305,
#  'face': 306,
#  '@HillaryClinton': 307,
#  'always': 308,
#  '#KKKorGOP': 309,
#  'every': 310,
#  'given': 311,
#  '@Lrihendry:': 312,
#  'Scott': 313,
#  'political': 314,
#  'After': 315,
#  'word': 316,
#  'job': 317,
#  'ratings.': 318,
#  'rights': 319,
#  'Twitter': 320,
#  'candidates,': 321,
#  'looking': 322,
#  'answer': 323,
#  'plan': 324,
#  'raising': 325,
#  '#GOPD…': 326,
#  'That': 327,
#  'thing': 328,
#  'Marco': 329,
#  'control': 330,
#  '@GovChristie': 331,
#  '@goldietaylor:': 332,
#  'Carly': 333,
#  'Debate': 334,
#  '#GOPDebates.': 335,
#  'In': 336,
#  'country': 337,
#  'sure': 338,
#  'tonight.': 339,
#  'Presidential': 340,
#  'Ask': 341,
#  'Last': 342,
#  'those': 343,
#  'way': 344,
#  'actually': 345,
#  'When': 346,
#  'Fiorina': 347,
#  'thinks': 348,
#  '#BlackLivesMatter': 349,
#  'forward': 350,
#  'purpose': 351,
#  '@tedcruz': 352,
#  'back': 353,
#  "I've": 354,
#  'give': 355,
#  'Look': 356,
#  'One': 357,
#  'hands.': 358,
#  '#GOPDebate?': 359,
#  'Oh': 360,
#  'ME': 361,
#  'then': 362,
#  'here': 363,
#  'same': 364,
#  'NOT': 365,
#  'debate,': 366,
#  'presidential': 367,
#  'man': 368,
#  'debates': 369,
#  'love': 370,
#  'said,': 371,
#  'moderators': 372,
#  '?': 373,
#  'Party': 374,
#  'leader': 375,
#  'legitimate': 376,
#  'do.': 377,
#  'truth,': 378,
#  'Dear': 379,
#  'call': 380,
#  'nails': 381,
#  'look': 382,
#  'watched': 383,
#  'admit': 384,
#  '@ericstonestreet:': 385,
#  'Cam': 386,
#  '@RealBenCarson': 387,
#  'asked': 388,
#  '@larryelder:': 389,
#  "Wallace's": 390,
#  '1': 391,
#  'all.': 392,
#  'These': 393,
#  'Hey': 394,
#  'Can': 395,
#  'show': 396,
#  'thought': 397,
#  'wants': 398,
#  'lead': 399,
#  '@marcorubio': 400,
#  'Trump,': 401,
#  'ever': 402,
#  'new': 403,
#  'saying': 404,
#  'President,': 405,
#  'Republicans': 406,
#  'John': 407,
#  'party': 408,
#  'down': 409,
#  'To': 410,
#  '@RandPaul': 411,
#  'nine': 412,
#  '"Megyn,': 413,
#  '#Trump2016': 414,
#  'nomination."': 415,
#  '@BettyFckinWhite:': 416,
#  'too': 417,
#  'which': 418,
#  '.': 419,
#  'getting': 420,
#  'But': 421,
#  "Trump's": 422,
#  'running': 423,
#  'needs': 424,
#  'seen': 425,
#  'frontrunner': 426,
#  "women's": 427,
#  'little': 428,
#  'let': 429,
#  'against': 430,
#  'making': 431,
#  'tonight': 432,
#  'fight': 433,
#  'THE': 434,
#  'enough': 435,
#  'Cruz,': 436,
#  '@GOP': 437,
#  'things': 438,
#  'order': 439,
#  'black': 440,
#  'learned': 441,
#  'Clinton': 442,
#  'everyone': 443,
#  'guys': 444,
#  'woman': 445,
#  'believe': 446,
#  'Enjoyed': 447,
#  '#DemocraticDebates': 448,
#  'next.': 449,
#  'illegal': 450,
#  'care': 451,
#  'All': 452,
#  'Democrats': 453,
#  '=': 454,
#  'another': 455,
#  'nothing': 456,
#  'makes': 457,
#  '#FoxDebate': 458,
#  'Trump:': 459,
#  'speak.': 460,
#  'it,': 461,
#  'bad': 462,
#  'discussing': 463,
#  'white': 464,
#  'looks': 465,
#  'feel': 466,
#  '@JebBush': 467,
#  'keep': 468,
#  'closing': 469,
#  'TV': 470,
#  '2016': 471,
#  'u': 472,
#  'media': 473,
#  'Huckabee.': 474,
#  'double-digit': 475,
#  '@GovMikeHuckabee': 476,
#  'stop': 477,
#  'calling': 478,
#  'Dr.': 479,
#  '@DonnieWahlberg:': 480,
#  "That's": 481,
#  'news': 482,
#  '@jamiaw:': 483,
#  'things"-Mike': 484,
#  '--': 485,
#  'run': 486,
#  'before': 487,
#  'person': 488,
#  'bodies': 489,
#  'came': 490,
#  'hard': 491,
#  'fact': 492,
#  'Watching': 493,
#  'Reagan': 494,
#  "wasn't": 495,
#  'night?': 496,
#  'up.': 497,
#  'favorite': 498,
#  'help': 499,
#  'US': 500,
#  'lot': 501,
#  '@SalMasekela:': 502,
#  'day': 503,
#  'debate?': 504,
#  'put': 505,
#  'She': 506,
#  '!': 507,
#  'hell': 508,
#  'night,': 509,
#  "I'll": 510,
#  'THIS': 511,
#  'part': 512,
#  'Now': 513,
#  'president.': 514,
#  'own': 515,
#  'Has': 516,
#  'away': 517,
#  'brought': 518,
#  'problem': 519,
#  '5': 520,
#  'Carson,': 521,
#  '4': 522,
#  'biggest': 523,
#  'Mike': 524,
#  'live': 525,
#  '@JohnKasich': 526,
#  'civil': 527,
#  'mention': 528,
#  'important': 529,
#  '#p2': 530,
#  'Do': 531,
#  'question?': 532,
#  'social': 533,
#  'clear': 534,
#  '...': 535,
#  'guy': 536,
#  "that's": 537,
#  'Tonight': 538,
#  'http://t.co/Zy12bdUkx9': 539,
#  'hate': 540,
#  '@BretBaier': 541,
#  'gave': 542,
#  'LOL': 543,
#  'issues': 544,
#  'seems': 545,
#  'come': 546,
#  'deserve': 547,
#  'whole': 548,
#  'today': 549,
#  'two': 550,
#  'voting': 551,
#  '@ScottWalker': 552,
#  'may': 553,
#  "isn't": 554,
#  'Americans': 555,
#  'gay': 556,
#  'now.': 557,
#  'From': 558,
#  'start': 559,
#  'audience': 560,
#  'went': 561,
#  'took': 562,
#  'world': 563,
#  'called': 564,
#  'years': 565,
#  'There': 566,
#  'misogyny': 567,
#  'process': 568,
#  'while': 569,
#  'Trump.': 570,
#  'Iran': 571,
#  'anything': 572,
#  'pretty': 573,
#  'terrorism.': 574,
#  'Christian': 575,
#  'w/': 576,
#  '@ChrisChristie': 577,
#  'under': 578,
#  "they're": 579,
#  '3': 580,
#  'president': 581,
#  'climate': 582,
#  'ALL': 583,
#  '#DebateWithBernie': 584,
#  'single': 585,
#  'On': 586,
#  '#MegynKelly': 587,
#  '#GOPdebate:': 588,
#  'used': 589,
#  'code': 590,
#  'woman.': 591,
#  'time.': 592,
#  'voters': 593,
#  'campaign': 594,
#  'something': 595,
#  'find': 596,
#  'must': 597,
#  'having': 598,
#  'him.': 599,
#  'answers': 600,
#  'Good': 601,
#  'happened.': 602,
#  'For': 603,
#  'focus': 604,
#  'told': 605,
#  '@YouTube': 606,
#  "Don't": 607,
#  'remove': 608,
#  'green': 609,
#  'heard': 610,
#  'performance': 611,
#  'abortion': 612,
#  'IS': 613,
#  'point': 614,
#  'tax': 615,
#  'fucking': 616,
#  'http://t.co/AuhlNZa3Ww': 617,
#  'apple': 618,
#  'martini': 619,
#  '@mozgovaya:': 620,
#  'First': 621,
#  'between': 622,
#  "Here's": 623,
#  'saw': 624,
#  'i': 625,
#  'work': 626,
#  'direct': 627,
#  '#GOPDeb…': 628,
#  'TO': 629,
#  'life': 630,
#  'most.': 631,
#  'ratings': 632,
#  'Was': 633,
#  'race': 634,
#  'http://t.c…': 635,
#  'At': 636,
#  'bunch': 637,
#  'both': 638,
#  'U.S.': 639,
#  'w': 640,
#  'send': 641,
#  'fun': 642,
#  'hugged': 643,
#  'Planned': 644,
#  'far': 645,
#  'gonna': 646,
#  '1st': 647,
#  'http:/…': 648,
#  'moment': 649,
#  'By': 650,
#  'shit': 651,
#  'Thank': 652,
#  "Can't": 653,
#  '#ccot': 654,
#  'well': 655,
#  '"social': 656,
#  'stage.': 657,
#  'primaries.': 658,
#  'issues"': 659,
#  'full': 660,
#  'His': 661,
#  'Great': 662,
#  'Of': 663,
#  'received': 664,
#  "Who's": 665,
#  'Immigration': 666,
#  'without': 667,
#  'Bernie': 668,
#  'less': 669,
#  '#GOP…': 670,
#  'YOU': 671,
#  'hair': 672,
#  '@': 673,
#  '"We': 674,
#  'state': 675,
#  'Well': 676,
#  '@pattonoswalt:': 677,
#  'http…': 678,
#  'change': 679,
#  "couldn't": 680,
#  '.@realDonaldTrump': 681,
#  'missed': 682,
#  'Women': 683,
#  'Are': 684,
#  'tough': 685,
#  'mentioned': 686,
#  'killing': 687,
#  '#GO…': 688,
#  'end': 689,
#  'realize': 690,
#  'reality': 691,
#  'trump': 692,
#  'its': 693,
#  'talks': 694,
#  'Cancel': 695,
#  'Best': 696,
#  'Walker,': 697,
#  '@TheBaxterBean:': 698,
#  'true': 699,
#  'Rosie': 700,
#  'wait': 701,
#  'respect': 702,
#  'giving': 703,
#  'left': 704,
#  'group': 705,
#  '@SenTedCruz': 706,
#  'thoughts': 707,
#  'become': 708,
#  'also': 709,
#  'nobody': 710,
#  'nights': 711,
#  'Does': 712,
#  'Hold': 713,
#  'sexuality': 714,
#  'line': 715,
#  'http://t…': 716,
#  'primary': 717,
#  '#GOPDe…': 718,
#  'times': 719,
#  'until': 720,
#  'Your': 721,
#  '|': 722,
#  'play': 723,
#  'Ronald': 724,
#  'GO': 725,
#  'asking': 726,
#  'boy:': 727,
#  'tight,': 728,
#  'TwitterLand': 729,
#  'comments': 730,
#  'Paul,': 731,
#  '#CruzCrew': 732,
#  'htt…': 733,
#  'might': 734,
#  'wonder': 735,
#  '@FrankLuntz': 736,
#  'Mexican': 737,
#  'women.': 738,
#  '#KellyFile': 739,
#  'war': 740,
#  'deal': 741,
#  'entertaining': 742,
#  'Will': 743,
#  'politicians': 744,
#  "tonight's": 745,
#  'pissed': 746,
#  'showed': 747,
#  'perfect': 748,
#  '-I': 749,
#  'anointed': 750,
#  'calls': 751,
#  'http://…': 752,
#  'http:…': 753,
#  'me.': 754,
#  'Go': 755,
#  '#RandPaul': 756,
#  'totally': 757,
#  '8': 758,
#  'wins': 759,
#  'Florida': 760,
#  'gone': 761,
#  'Wasserman-Schultz': 762,
#  'words': 763,
#  'hope': 764,
#  'alien': 765,
#  'immigration': 766,
#  "aren't": 767,
#  'With': 768,
#  '#morningjoe': 769,
#  '@kwrcrow:': 770,
#  '-Can': 771,
#  '-So,': 772,
#  'no?': 773,
#  'ISIS': 774,
#  'Social': 775,
#  'name': 776,
#  'ht…': 777,
#  'people.': 778,
#  'pay': 779,
#  'stand': 780,
#  '#Kasich': 781,
#  'half': 782,
#  'issue': 783,
#  'everything': 784,
#  'gun': 785,
#  'through': 786,
#  'kind': 787,
#  'around': 788,
#  'U': 789,
#  'fair': 790,
#  'kids': 791,
#  'few': 792,
#  'Farrakhan': 793,
#  'Bor...': 794,
#  'old': 795,
#  'coming': 796,
#  'New': 797,
#  'minutes': 798,
#  '#GOPDeba…': 799,
#  'tonight,': 800,
#  'once': 801,
#  'Anyone': 802,
#  '#TCOT': 803,
#  'damn': 804,
#  'right,': 805,
#  '#FOXNEWSDEBATE': 806,
#  'wondering': 807,
#  'immigration,': 808,
#  '#GOPDebates?': 809,
#  '#CantTrustABush': 810,
#  'http://t.…': 811,
#  'class': 812,
#  'destroy': 813,
#  'police': 814,
#  'White': 815,
#  '#GOPClownCar': 816,
#  'record': 817,
#  'place': 818,
#  'probably': 819,
#  'lost': 820,
#  '#Carly2016': 821,
#  'https://t.co/lkLfFN2LFy': 822,
#  'winners': 823,
#  'past': 824,
#  "Let's": 825,
#  'Carson:': 826,
#  'So,': 827,
#  'politically': 828,
#  'Sanders': 829,
#  'ass': 830,
#  'DC': 831,
#  'person.': 832,
#  'Debates.': 833,
#  'morning': 834,
#  'done': 835,
#  "You're": 836,
#  'Jon': 837,
#  'wish': 838,
#  'instead': 839,
#  'OF': 840,
#  'himself': 841,
#  'agree': 842,
#  'speak': 843,
#  'please': 844,
#  'taking': 845,
#  'head': 846,
#  'top': 847,
#  'Two': 848,
#  'Back': 849,
#  'facing': 850,
#  'https://t…': 851,
#  '#GOPDebates,': 852,
#  'loved': 853,
#  'Bush,': 854,
#  'More': 855,
#  ':': 856,
#  'response': 857,
#  '#Fiorina': 858,
#  'election': 859,
#  '@DWStweets': 860,
#  'vs': 861,
#  "He's": 862,
#  'Please': 863,
#  '#JonVoyage': 864,
#  'themselves': 865,
#  "we're": 866,
#  'Then': 867,
#  'Very': 868,
#  'pledge': 869,
#  'Only': 870,
#  'use': 871,
#  'friends': 872,
#  'spent': 873,
#  'Walker:': 874,
#  'republican': 875,
#  '#FF': 876,
#  'read': 877,
#  'Our': 878,
#  'commercial': 879,
#  'hangover': 880,
#  'laws': 881,
#  '@PuestoLoco:': 882,
#  'headed': 883,
#  'TED!!': 884,
#  'http://t.co/8S67pz8a4A': 885,
#  'speaking': 886,
#  'Democrat': 887,
#  'refuse': 888,
#  '#WakeUpAmerica': 889,
#  '2nd': 890,
#  'points': 891,
#  'post': 892,
#  'check': 893,
#  'again': 894,
#  'office': 895,
#  'statement': 896,
#  'miss': 897,
#  'down.': 898,
#  'rather': 899,
#  'Most': 900,
#  'marriage': 901,
#  'analysis': 902,
#  'Kelly,': 903,
#  'knows': 904,
#  'Let': 905,
#  'sober': 906,
#  'untill': 907,
#  'God?!': 908,
#  'hopefuls?!': 909,
#  'America?!': 910,
#  'Brotherhood': 911,
#  '@marymauldin:': 912,
#  'http://t.co…': 913,
#  'tweet': 914,
#  'government': 915,
#  'Black': 916,
#  'impressed': 917,
#  'playing': 918,
#  'night:': 919,
#  'Even': 920,
#  'conservative': 921,
#  'Koch': 922,
#  "let's": 923,
#  'least': 924,
#  'People': 925,
#  '#IranDeal': 926,
#  '"I\'m': 927,
#  'already': 928,
#  'Future': 929,
#  'interesting': 930,
#  "Cruz's": 931,
#  'maybe': 932,
#  'sense': 933,
#  'unfathomable': 934,
#  'postmortem': 935,
#  '#SURREAL': 936,
#  'NO': 937,
#  'AND': 938,
#  'moments': 939,
#  'Status': 940,
#  '#CarlyFiorina': 941,
#  'that.': 942,
#  'Maybe': 943,
#  'us.': 944,
#  'this.': 945,
#  "there's": 946,
#  '#BenCarson': 947,
#  'year': 948,
#  'poor': 949,
#  'wanted': 950,
#  'changed': 951,
#  'Closing': 952,
#  'killed': 953,
#  'Facebook': 954,
#  '#UniteBlue': 955,
#  'establishment': 956,
#  'Check': 957,
#  'Love': 958,
#  'racism': 959,
#  '#TedCruz2016': 960,
#  'attacks': 961,
#  '#GOPtbt': 962,
#  'personal': 963,
#  'takes': 964,
#  'loser': 965,
#  'absolutely': 966,
#  'men,': 967,
#  'business': 968,
#  'thinking': 969,
#  '#GOPDEBATES': 970,
#  '#toot': 971,
#  '@Desdemona4U:': 972,
#  '@LibertyU': 973,
#  '#Walker16': 974,
#  'An': 975,
#  'cut': 976,
#  'almost': 977,
#  'crazy': 978,
#  'shut': 979,
#  'future': 980,
#  '#tlot': 981,
#  'politics': 982,
#  '@foxnews': 983,
#  'either': 984,
#  'liberal': 985,
#  "we'll": 986,
#  'yet': 987,
#  '@CNN': 988,
#  'proud': 989,
#  'out.': 990,
#  'Some': 991,
#  'Megan': 992,
#  'candidate.': 993,
#  'free': 994,
#  'knew': 995,
#  "shouldn't": 996,
#  '#trump': 997,
#  'China': 998,
#  'fuck': 999,
#  ...}

# %% [markdown]
# ### Tharg smash problem!

# %%
#method 1
words = list(set(word_list))  # get a list of unique words.
counter=0
enc_brute1={}
dec_brute1={}
for i in words:
    enc_brute1[i] = counter
    dec_brute1[counter] = i
    counter = counter + 1

# %%
enc_brute1  #note that they are in a different order.  Doesn't matter.  Its just a map
# Out:
# {'Wallace,': 0,
#  'missed.': 1,
#  'forway': 2,
#  '@kajawhitehouse:': 3,
#  'surprised': 4,
#  'carson': 5,
#  'https://t.co/lMzNoMpFMW': 6,
#  'promoting': 7,
#  'forgettable': 8,
#  'http://t.co/JI0J6pNSIS': 9,
#  'proper': 10,
#  '-Trump': 11,
#  'bored,': 12,
#  '@FlashReport': 13,
#  'Reactions': 14,
#  'COAST': 15,
#  'http://t.co/SiNu1AStpS': 16,
#  'wake': 17,
#  '@genethelawyer:': 18,
#  'divide': 19,
#  'WAS': 20,
#  '@savvyliterate:': 21,
#  'https://t.co/M6DbM4SHY3': 22,
#  'vote:': 23,
#  '“@TheEconomist:': 24,
#  '"Freedom': 25,
#  'video.…': 26,
#  '@atlcav:': 27,
#  'applied': 28,
#  '@DumbGayBatman:': 29,
#  '"they\'re': 30,
#  'doctor.': 31,
#  'conservation,': 32,
#  'Matter': 33,
#  'ISIS)': 34,
#  'senators': 35,
#  '@chi_kimura:': 36,
#  'http://t.co/5LACcafUXW': 37,
#  '@ira:': 38,
#  'healthcare:': 39,
#  'http://t.co/Zw35DkUozi': 40,
#  'alone': 41,
#  'http://t.co/p4DK0LmN2q': 42,
#  '—@JebBush,': 43,
#  '"Pregnant': 44,
#  'scared.': 45,
#  '@DrBenCarson2016': 46,
#  'staked': 47,
#  '#NYTimes': 48,
#  '(As': 49,
#  'Buzzers': 50,
#  'http://t.co/KgKYIJRww9': 51,
#  'good!!': 52,
#  'Garbage': 53,
#  'eggs': 54,
#  'vs,': 55,
#  'JERRY!': 56,
#  'conducted': 57,
#  '#tiot': 58,
#  'spelling': 59,
#  'becoming': 60,
#  "TONIGHT's": 61,
#  'ignorant': 62,
#  'average': 63,
#  'mob': 64,
#  'freeloaders."': 65,
#  'roundup': 66,
#  '"fat': 67,
#  'manufacturing': 68,
#  '#climatechange.': 69,
#  'Invisalign?': 70,
#  'semiautomatic': 71,
#  '@AdamCarollaShow': 72,
#  'censoring': 73,
#  '@NowWithALEX': 74,
#  'DONT': 75,
#  '#Profound': 76,
#  'Someone,': 77,
#  'Kidding': 78,
#  'SOCaiL': 79,
#  'frankly,': 80,
#  '#scottwalker': 81,
#  'Shocking': 82,
#  'easy.': 83,
#  '@RobertsMSNBC': 84,
#  'insomniacs': 85,
#  '@AnnStokes55': 86,
#  'http://t.co/gWVflrsZk4': 87,
#  'BACK!': 88,
#  'http://t.co/TsGXHIlPy2': 89,
#  'gaydayslosangeles': 90,
#  'cure...': 91,
#  '@NYTimeskrugman': 92,
#  '#ChrisWallace,': 93,
#  'Reasonable': 94,
#  'do!': 95,
#  '#BlackEagle': 96,
#  'rare)': 97,
#  '@edwrather:': 98,
#  'veiw': 99,
#  'payer...': 100,
#  '@bobcesca_go:': 101,
#  'TMZ': 102,
#  'ratio': 103,
#  '#GOPDebate.”': 104,
#  '@TheLadyValor': 105,
#  'disrespected': 106,
#  '"WE\'RE': 107,
#  'right"': 108,
#  'detached': 109,
#  '7.': 110,
#  'enuff': 111,
#  '?#GOPDebates': 112,
#  'http://t.co/nb9khF3DbM': 113,
#  '@halrudnick:': 114,
#  'https://t.co/Ua4eh0STfT': 115,
#  'picks': 116,
#  'EVERYONE': 117,
#  '#OnFleek': 118,
#  'pot': 119,
#  '(because': 120,
#  'bloviating': 121,
#  '#SadClown': 122,
#  'advising': 123,
#  '#UnfairWorld': 124,
#  'Crying': 125,
#  '--Scott': 126,
#  'already.': 127,
#  'booze': 128,
#  'http://t.co/1sk3TqNNNV': 129,
#  'card': 130,
#  'http://t.co/Vb5bDjR1K9': 131,
#  '@Erasing_Us:': 132,
#  '“Ya': 133,
#  'happened.': 134,
#  'attention.': 135,
#  '#GOPDebates.': 136,
#  'https://t.co/e3hJMpoezK': 137,
#  '#NRA': 138,
#  '8-year-old': 139,
#  'focusing': 140,
#  '#Benghazi.': 141,
#  '-D': 142,
#  'Education?': 143,
#  'weekend,': 144,
#  '"gay': 145,
#  'government': 146,
#  '*goes': 147,
#  'crazier': 148,
#  '@BernieSanders': 149,
#  '#charleskrauthammer': 150,
#  'theology.': 151,
#  'Islam."': 152,
#  'FUNNY!': 153,
#  'commercial.': 154,
#  'detailed': 155,
#  'YALL': 156,
#  'http://t.co/Xx2BP5QKcY': 157,
#  "men's": 158,
#  'https://t.co/P2D2SEwvvl': 159,
#  'http://t.co/iSsjFq9YSN': 160,
#  'https://t.co/26v9hrAHK2': 161,
#  'Again.': 162,
#  '(mostly)': 163,
#  'smacked': 164,
#  '#NoCredibility': 165,
#  'Gets': 166,
#  'America’s': 167,
#  'http://t.co/GI9kAKuee1': 168,
#  'OUTTA': 169,
#  'breaks:': 170,
#  'car.': 171,
#  'toddler:': 172,
#  '#SoundCloud?': 173,
#  'da': 174,
#  'problems(personal': 175,
#  'THIS,': 176,
#  'Solution:': 177,
#  'Officer': 178,
#  'athletics': 179,
#  'normally': 180,
#  'E-Verify!': 181,
#  '"tried': 182,
#  'occasions': 183,
#  'skiing': 184,
#  "boy's": 185,
#  'soon,': 186,
#  "boo'ed?": 187,
#  'quite,': 188,
#  'howling.': 189,
#  'http://t.co/DowgeHdbgl': 190,
#  '@Diplomtc_Immnty:': 191,
#  'EVER-this': 192,
#  'discussed': 193,
#  'assistance': 194,
#  'time,': 195,
#  'unknown': 196,
#  '@GameofOwns': 197,
#  '@usedtobgop:': 198,
#  'abusing': 199,
#  'http://t.co/9ZZFLChJQO': 200,
#  'putin.': 201,
#  'bigger,': 202,
#  'Trans': 203,
#  'panel,': 204,
#  'English,': 205,
#  'DC': 206,
#  'precious': 207,
#  'Vital': 208,
#  '#lebrojames': 209,
#  '@KirbyWilson88': 210,
#  'slams': 211,
#  'corporate': 212,
#  'Mall': 213,
#  '@StudyingLiberty:': 214,
#  'suicide': 215,
#  'respects': 216,
#  'https://t.co/JudMM4iT3j': 217,
#  'UNDERSTAND': 218,
#  '.@Skye820': 219,
#  '"Maybe': 220,
#  'Avoid': 221,
#  '#Io…': 222,
#  '@Wilberforce91:': 223,
#  'Oba…': 224,
#  'wallets': 225,
#  'wherever': 226,
#  'http://t.co/dl5mBjhJuG': 227,
#  'guy"...Ben': 228,
#  '#damage': 229,
#  'SHOTS': 230,
#  'asking.': 231,
#  'plunged': 232,
#  '"Marco': 233,
#  'smear': 234,
#  'warrant,': 235,
#  'Leaks': 236,
#  'Enough!': 237,
#  '#SanDiego': 238,
#  'Effie': 239,
#  'http://t.co/mrhu93tQDM': 240,
#  '@oftenimprudent:': 241,
#  'Dodd-Frank': 242,
#  'it..': 243,
#  'https://t.co/NfoIPr3Vej': 244,
#  'Sept.': 245,
#  'Live': 246,
#  '$21MILLION.': 247,
#  'beautiful': 248,
#  'insulted': 249,
#  'included,': 250,
#  '"god"': 251,
#  'donut': 252,
#  'http://t.co/0Wr4jcUsvs': 253,
#  'flesh': 254,
#  'Allows': 255,
#  'http://t.co/iJYmUd0nV4': 256,
#  '#hillaryclinton': 257,
#  'straits': 258,
#  '@debrajsaunders': 259,
#  'just': 260,
#  'activism': 261,
#  '@jodiwilldare:': 262,
#  'LLC,': 263,
#  '#KKKor…': 264,
#  'funerals': 265,
#  'FrankLuntz:': 266,
#  "'You": 267,
#  'Presidency.': 268,
#  'quipped': 269,
#  'night...': 270,
#  'telling.': 271,
#  'conditional.': 272,
#  'believability,': 273,
#  '@nhdogmom:': 274,
#  '@millerkevinc:': 275,
#  'sickened': 276,
#  '#DebateWithBe…': 277,
#  '#jobs': 278,
#  '#gopdebates...': 279,
#  'snakes.': 280,
#  'Show!': 281,
#  'women!!': 282,
#  'Chinese': 283,
#  '#satire': 284,
#  'Merkel.': 285,
#  'Obviously': 286,
#  '@YourYakiri:': 287,
#  'effectively': 288,
#  "want'": 289,
#  'Ya': 290,
#  '#DebateWithBernie.': 291,
#  'accountable': 292,
#  'people!!': 293,
#  'setups': 294,
#  '@jan4usa': 295,
#  'Nobody.': 296,
#  'art?': 297,
#  'http://t.co/o2psPH6MZv': 298,
#  'hardest-hitting': 299,
#  '"12': 300,
#  '@Anisha_S113:': 301,
#  'mouthful.': 302,
#  'Trump",': 303,
#  'cardboard': 304,
#  '#Pinknazism': 305,
#  'plastic': 306,
#  'Facebook:': 307,
#  '#myeyesjustrolledouttamyhead': 308,
#  'Outrageous': 309,
#  '@JanelleRettig:': 310,
#  'passive.': 311,
#  'Jewish': 312,
#  'favorites': 313,
#  '#ClownCar2016': 314,
#  'team!': 315,
#  'UNBORN': 316,
#  'BALLS': 317,
#  'primarily': 318,
#  'materials.': 319,
#  '@ZanP:': 320,
#  'things."': 321,
#  'birth?': 322,
#  "nation'…": 323,
#  'luck': 324,
#  '"Koch': 325,
#  '#BlackLivesMatter': 326,
#  'Man.': 327,
#  'surgeons': 328,
#  '@bannerite:': 329,
#  'worldview': 330,
#  'my.': 331,
#  "Carter's": 332,
#  'brothers,': 333,
#  'https://t.co/M2zI6acgnO': 334,
#  'toupee?': 335,
#  '@cityofsavannah,': 336,
#  'NANA': 337,
#  'bump': 338,
#  'OMG': 339,
#  'sti…': 340,
#  'guys!': 341,
#  'bill': 342,
#  '"Knowing': 343,
#  'slogan.': 344,
#  '@totalgolfmove:': 345,
#  '49%': 346,
#  '🇺🇸s': 347,
#  'backup': 348,
#  'pertinent.': 349,
#  '@TedCruz': 350,
#  '@EthanObama:': 351,
#  'announces': 352,
#  'products...': 353,
#  'hardships': 354,
#  '#biasnews': 355,
#  'future.': 356,
#  'redeeming': 357,
#  'close': 358,
#  '@AaronBlakeWP': 359,
#  'ride': 360,
#  'Frank?': 361,
#  'brutally': 362,
#  'http://t.co/HB39E72Urg': 363,
#  'AriDavidUSA:': 364,
#  'voices."': 365,
#  'glasses,': 366,
#  '#FantasyGOPDebates': 367,
#  'damn,': 368,
#  'bastardized': 369,
#  '3-6': 370,
#  '@realDonaldTrump...': 371,
#  'lot."': 372,
#  'listened': 373,
#  'Brittney': 374,
#  '@_NateDrake:': 375,
#  'exactly.': 376,
#  '@MakinH15TORY:': 377,
#  'https:/…': 378,
#  '#Chemieunfal…': 379,
#  'for:': 380,
#  'slobs': 381,
#  'smartest': 382,
#  'unhniged': 383,
#  'http://t.co/V0d82zUfgV"': 384,
#  'http://t.co/d5c…': 385,
#  'brown': 386,
#  '@Squintz1983': 387,
#  'Party.': 388,
#  'unexpected': 389,
#  '@Torchie123:': 390,
#  '#ISIS.': 391,
#  'liars.': 392,
#  'ha…': 393,
#  'laundry…': 394,
#  'describing': 395,
#  'FB': 396,
#  'Dont': 397,
#  'said…': 398,
#  '"hidden': 399,
#  'teen': 400,
#  'sober': 401,
#  'FARCE.': 402,
#  'Sunday': 403,
#  'preparing': 404,
#  'results.': 405,
#  'replaces': 406,
#  'off:': 407,
#  '#@ScottWalker': 408,
#  'twink': 409,
#  'continual': 410,
#  'During': 411,
#  'States"': 412,
#  'ANY': 413,
#  'Roxy': 414,
#  'http://t.co/8Y8GkqTnvK': 415,
#  'root…': 416,
#  'sexism"': 417,
#  'otherwise': 418,
#  'independent!': 419,
#  'Years': 420,
#  'http://t.co/B7TI3hVn7p': 421,
#  'proud.': 422,
#  'commercial': 423,
#  '@MichelleHux:': 424,
#  'recommended': 425,
#  '#startup': 426,
#  'House': 427,
#  'smaller': 428,
#  'lol)': 429,
#  '#2015...': 430,
#  'productive.': 431,
#  '@sfchronicle': 432,
#  'defeated.': 433,
#  'Engel': 434,
#  'quoting': 435,
#  '@monteiro': 436,
#  'mess,': 437,
#  'http://t.co/Q3BpYSeSuE': 438,
#  '#JVteam?': 439,
#  'WINS!': 440,
#  'camped': 441,
#  'moonwalking': 442,
#  'crowd)': 443,
#  'vagina.': 444,
#  'pimps...': 445,
#  'different.': 446,
#  '@Kiplin…': 447,
#  'http://t.co/i…': 448,
#  'fared': 449,
#  'witness': 450,
#  '@schmitte': 451,
#  'yeah.': 452,
#  'SNAP': 453,
#  'jaw': 454,
#  'politician,': 455,
#  'decreased,': 456,
#  'According2my': 457,
#  '#epicf…': 458,
#  'saying.': 459,
#  'torpedo': 460,
#  '@Jenism101:': 461,
#  'friends,': 462,
#  'https://t.co/Km9maqD4S8': 463,
#  'https://t.co/qRQCYM2K3d': 464,
#  'now"': 465,
#  '@erinrook:': 466,
#  'Committed': 467,
#  'Duggar': 468,
#  'help': 469,
#  'SHIT': 470,
#  '@IraHayes': 471,
#  'selfie': 472,
#  'value?': 473,
#  'nor': 474,
#  '@TripLangley:': 475,
#  '#Dataviz': 476,
#  '#presidentialprimaries…': 477,
#  'Crawford': 478,
#  '@nazrag:': 479,
#  '@KenCageRepo': 480,
#  'https://t.co/iCqusR68AD': 481,
#  'hotels.': 482,
#  'court.': 483,
#  '#bencarson': 484,
#  'superpower': 485,
#  '😭😭': 486,
#  'Santorum': 487,
#  '(vs': 488,
#  'pudding': 489,
#  '@Brizzandonn:': 490,
#  "That'd": 491,
#  'al-awlaki': 492,
#  'citizenship': 493,
#  'audience:': 494,
#  'Footnote': 495,
#  'privacy': 496,
#  'GOVERNOR': 497,
#  '#SECPrimary...': 498,
#  'Makes': 499,
#  'http://t.co/kbJhqAc68x': 500,
#  'Immigration,': 501,
#  'kinds': 502,
#  '42%.': 503,
#  '#theSwaggerLookedFamiliar': 504,
#  'culture': 505,
#  '@Garrison_JA:': 506,
#  'man,': 507,
#  'http://t.co/WhLKEkq2FM': 508,
#  'frustrated': 509,
#  'amount".': 510,
#  'https://t.co/1mtTUG98Ch': 511,
#  'STATEMENTS': 512,
#  'laugh': 513,
#  'prime': 514,
#  '@NBCNews': 515,
#  'hair,': 516,
#  '#ThreeStooges': 517,
#  'financials': 518,
#  '#TDS': 519,
#  'dudes': 520,
#  '"9/11': 521,
#  'misinformed': 522,
#  '#shevotes': 523,
#  'Poised,': 524,
#  'Affair': 525,
#  '@DanSpeaksTruth:': 526,
#  'PLZ': 527,
#  'hopefully': 528,
#  '@NinjaEconomics:': 529,
#  'http://t.co/5ImGwdRL4G': 530,
#  '#GOPDebate?': 531,
#  'questions--and': 532,
#  '"all': 533,
#  '@billmaher': 534,
#  'kid,': 535,
#  'n2': 536,
#  '"Miss': 537,
#  'issue': 538,
#  'take.': 539,
#  'illegals': 540,
#  '@emorydebate': 541,
#  'Wuuuuuuuut?': 542,
#  '#God': 543,
#  'exon': 544,
#  'notes': 545,
#  'Substance.A': 546,
#  'interview,': 547,
#  'again': 548,
#  '60': 549,
#  '#kkkorgop': 550,
#  '@mashable:': 551,
#  'chart': 552,
#  'Neat': 553,
#  'exist': 554,
#  'Laughs': 555,
#  'fave': 556,
#  'center!:)': 557,
#  '@NadaMoo:': 558,
#  'technology': 559,
#  'U': 560,
#  '@brucepknight:': 561,
#  'there."': 562,
#  '@tedcruz': 563,
#  'beta-male': 564,
#  '@GovWal…': 565,
#  '"Your': 566,
#  'blasts': 567,
#  'Expose': 568,
#  '"@Pieter_Gericke': 569,
#  'https://t.co/QZMfehR8VF': 570,
#  '@jjday10:': 571,
#  'w/@ghook': 572,
#  '@ChrisStirewalt:': 573,
#  'sample': 574,
#  'Nostradamus': 575,
#  'informati…': 576,
#  'Wallace...': 577,
#  'WIN;': 578,
#  'God:': 579,
#  'RAGE!': 580,
#  'http://t.co/m6aFfsKJmC': 581,
#  '@LarryOConnor': 582,
#  'support': 583,
#  '@MaryFolley:': 584,
#  'repeat': 585,
#  '@angela_rye:': 586,
#  'aged': 587,
#  'comments:': 588,
#  '@Politics_PR:': 589,
#  '#Obama': 590,
#  'Phew!': 591,
#  'Wanna': 592,
#  '@WhitneyNeal:': 593,
#  'terrifying': 594,
#  'thirsty.': 595,
#  'pimps".': 596,
#  '#StuporBowl': 597,
#  '@UniteBlueWI:': 598,
#  'Apple': 599,
#  'music': 600,
#  'poor,': 601,
#  '@OldRowOfficial:': 602,
#  'bankruptcy,': 603,
#  'blacks': 604,
#  'showed': 605,
#  'hand.': 606,
#  '#factcheck': 607,
#  'baffles': 608,
#  'Month': 609,
#  '#Jobs': 610,
#  'you"': 611,
#  'http://t.co/qvFMafvgu0': 612,
#  'Down👎🏼;': 613,
#  '3.)': 614,
#  'Andy': 615,
#  'Offended': 616,
#  'http://t.co/NdnRdWrQyF': 617,
#  "Let's": 618,
#  'lit…': 619,
#  'HIM': 620,
#  'covered': 621,
#  'commit': 622,
#  'Heading': 623,
#  'glasses': 624,
#  'forever.': 625,
#  '#jealousmuch': 626,
#  'target.': 627,
#  '@JayGeraghty:': 628,
#  'young': 629,
#  'LEFT': 630,
#  'playlist': 631,
#  '#CruzCrew': 632,
#  'SS/Medicare': 633,
#  '@Senate_GOPs': 634,
#  "'Jungleland'": 635,
#  'Especislly': 636,
#  'shadow': 637,
#  'blame': 638,
#  'Carly-NO': 639,
#  'Barnum': 640,
#  'dismember': 641,
#  'fallout': 642,
#  '"Any': 643,
#  "abortion's": 644,
#  'campaigns': 645,
#  'AwRIGHT': 646,
#  'http://t.co/T4N6dh3pZo': 647,
#  'http://t.co/2IeDJhem7F': 648,
#  'nauseous.': 649,
#  'Stooges': 650,
#  'hila…': 651,
#  'http://t.co/eha7FscJgX': 652,
#  'mascara?': 653,
#  '@LaPoliticsNow': 654,
#  'Everything': 655,
#  'http://t.co/ndgrhvpB4I': 656,
#  'officer': 657,
#  'SCARFACE.': 658,
#  'Earnings': 659,
#  "2nit's": 660,
#  'humility': 661,
#  '@RandPaul': 662,
#  '#US2016': 663,
#  '...now': 664,
#  '$80k': 665,
#  'argument': 666,
#  'So,': 667,
#  '#ModeratorFail': 668,
#  'pronouncing': 669,
#  'be."': 670,
#  '"penetrating': 671,
#  'impartial.': 672,
#  'Herbert': 673,
#  "?'s": 674,
#  'Dec.': 675,
#  'ages.': 676,
#  'http://t.co/9rD7GdZAGG': 677,
#  '"President': 678,
#  'demonstrated': 679,
#  'cried': 680,
#  'dinosaurs': 681,
#  '@RachLWhitehurst:': 682,
#  'bitch': 683,
#  'blog': 684,
#  'pope': 685,
#  'drastically.': 686,
#  '@DANEgerus:': 687,
#  'admits': 688,
#  '@csydelko:': 689,
#  'schools.': 690,
#  'rain': 691,
#  'http://t.co/vhL…': 692,
#  'Moment': 693,
#  '#kthanksbye': 694,
#  "'bimbo,'": 695,
#  'http://t.co/8xGtwK7ZUi': 696,
#  'Balanced"': 697,
#  'shootings,': 698,
#  'cooking': 699,
#  'http://t.co/iSlpTw9Sor': 700,
#  'Debate:': 701,
#  'SC': 702,
#  'Debate': 703,
#  '9/10/11!': 704,
#  'skipped': 705,
#  'terrorist': 706,
#  'height.': 707,
#  'Re-watching': 708,
#  'http://t.co/WJCpQl2Jor': 709,
#  '@FightFor15PA': 710,
#  'States': 711,
#  '-Piyush': 712,
#  'st…': 713,
#  '18': 714,
#  'since"': 715,
#  "q's": 716,
#  'https://t.co/pIcm3bn9Ma': 717,
#  'purchase': 718,
#  'OK,': 719,
#  'imagining': 720,
#  '@larryelder:': 721,
#  'drones)': 722,
#  'Adorbs.': 723,
#  '#GOPDEBATE:': 724,
#  'http://t.co/vJRFUPGVqn': 725,
#  'Putin': 726,
#  'experiment"': 727,
#  '@NewsyVideos': 728,
#  'economy!"': 729,
#  'to?': 730,
#  '@abgutman:': 731,
#  'catapult!!': 732,
#  '"Obama': 733,
#  'grow': 734,
#  'Timberlake': 735,
#  '@sassyandcowgirl:': 736,
#  'Them': 737,
#  'ht…': 738,
#  '@CNNMoney:': 739,
#  'bringer': 740,
#  '#Carly2016…': 741,
#  'drinking': 742,
#  '"@marcorubio': 743,
#  '@jmsummers:': 744,
#  'commercial."': 745,
#  '#AC360.': 746,
#  '(http://t.co/q6zBY…': 747,
#  '@Crutch4:': 748,
#  'Kasich.': 749,
#  'politics..#GOPDebates': 750,
#  "tryin'": 751,
#  'version': 752,
#  'ears?': 753,
#  'medial': 754,
#  'leaving....': 755,
#  'format.': 756,
#  'ALONE-': 757,
#  '#RavensNation': 758,
#  'beyond': 759,
#  'And...Rand': 760,
#  'thanks.': 761,
#  'Manufacturing': 762,
#  'alumna': 763,
#  'Show:': 764,
#  '@TeamKCP': 765,
#  '@Pudingtane:': 766,
#  'amusing': 767,
#  'e': 768,
#  'Stands': 769,
#  '#TrumpEffect”': 770,
#  '@scorpio5053:': 771,
#  'Fantasies': 772,
#  'worries.': 773,
#  'https://t.co/KYq3spOe9t': 774,
#  'roads': 775,
#  'priority?"': 776,
#  '#ClownCar': 777,
#  'Charles': 778,
#  'shames': 779,
#  'gluttons': 780,
#  'FACT:': 781,
#  'A-': 782,
#  'unicorns': 783,
#  'ACTIN': 784,
#  'Facebook!': 785,
#  'budgets...': 786,
#  'history......#GOPDebate': 787,
#  '@customjewel:': 788,
#  '#partyofthefuture': 789,
#  'epitome': 790,
#  'Liberals': 791,
#  '@Morning_Joe': 792,
#  'populace': 793,
#  '"pro-life"': 794,
#  'debates,': 795,
#  'guys?': 796,
#  'http://t.co/C1fFLfYReu”': 797,
#  '"roots",': 798,
#  'bats': 799,
#  'Steve': 800,
#  '@iDXR:': 801,
#  'wraps.': 802,
#  'i': 803,
#  'http://t.co/wktSBpOpzV': 804,
#  '@OTOOLEFAN:': 805,
#  '#newsnerd': 806,
#  'teachers.': 807,
#  'tanked': 808,
#  'PR': 809,
#  'reference.': 810,
#  'SQUIRREL!': 811,
#  'depress': 812,
#  'fire!': 813,
#  'classy': 814,
#  '"A"': 815,
#  'Lmfao!!!': 816,
#  '#junkies': 817,
#  'lol.': 818,
#  'dreadful': 819,
#  'http://t.co/IuwKYlUdMg': 820,
#  'Rand': 821,
#  'committing': 822,
#  'not....': 823,
#  'color,': 824,
#  "tonight'…": 825,
#  'ad': 826,
#  '@mKheywood:': 827,
#  'playbook.': 828,
#  '"me': 829,
#  '@SenTomCotton': 830,
#  'route': 831,
#  'soundbites.': 832,
#  'locally': 833,
#  'Family': 834,
#  '#HANNIBAL': 835,
#  'sport,': 836,
#  'progressives.': 837,
#  '#wiunion': 838,
#  '#bringingjobs': 839,
#  'Replace': 840,
#  'writing': 841,
#  "'In": 842,
#  '👍🏻-Trump,': 843,
#  'http://t.co/yEtxHn47xO': 844,
#  'legal?': 845,
#  'aching...': 846,
#  'gotta': 847,
#  '.@POTUS': 848,
#  'wtf': 849,
#  '@jimtrue48:': 850,
#  'Trumpians:': 851,
#  '@ziggylasvegas:': 852,
#  'NylonMag:': 853,
#  'unique': 854,
#  'wink': 855,
#  '#FrankLundt': 856,
#  '@WlZKHALlFA:': 857,
#  'http://t.co/FUAPQThMzg': 858,
#  'unit': 859,
#  'https://t.co/awBmpTMpUm': 860,
#  'VIDEO:': 861,
#  "who's": 862,
#  '.@GovernorPerry:': 863,
#  'bestest': 864,
#  'SCREAMING': 865,
#  'sarcastic': 866,
#  'rights.': 867,
#  'Right???': 868,
#  's…': 869,
#  '@BigBoyBaker:': 870,
#  '@McCormackJohn': 871,
#  'http://t.co/WzKTUUMiA5': 872,
#  'sexist:': 873,
#  'slight': 874,
#  'https://t.co/zHFnP1bnuj': 875,
#  '#ReallyAmerica': 876,
#  'whiny': 877,
#  '#BBHMM': 878,
#  '^answers^': 879,
#  'Mrs': 880,
#  'article!': 881,
#  'rocked': 882,
#  'Woo...': 883,
#  'http://t.co/hNgi4avB6x': 884,
#  'question!': 885,
#  'http://t.co/fcn61e8e3w': 886,
#  'thoughts!!!!!': 887,
#  'complete': 888,
#  'GOP!': 889,
#  'Bar': 890,
#  "y'all": 891,
#  'imagine': 892,
#  'http://t.co/8i7tgOCc7c': 893,
#  '#GOPdebates.': 894,
#  'senator': 895,
#  'elitist': 896,
#  'hv': 897,
#  '“@FoxNews:': 898,
#  'jed': 899,
#  'HARBOR': 900,
#  'Union-ish': 901,
#  'slip.': 902,
#  'to,': 903,
#  '@NYTimeskrugman:': 904,
#  'rooted': 905,
#  'fu*k': 906,
#  '"honest"': 907,
#  'FUN': 908,
#  'jobs.': 909,
#  'chided': 910,
#  'Truthfully': 911,
#  '@TamaraCG:': 912,
#  'ENVIRONMENT.': 913,
#  '#GOPDebate!': 914,
#  'stunning': 915,
#  '@tuckahoetommy:': 916,
#  '@NY1at': 917,
#  'Ohio': 918,
#  'http://t.co/2uCYuplUdO': 919,
#  'desperate.': 920,
#  'http://t.co/i83MHXnU9G': 921,
#  'cat': 922,
#  '@InvisibleObama': 923,
#  '@UrProbsJewish:': 924,
#  'Illiterates.': 925,
#  '@DadTimpf:': 926,
#  'thru': 927,
#  'Care': 928,
#  '#TheView': 929,
#  'deport': 930,
#  'Act': 931,
#  'http://t.co/4XvN7N5lv1': 932,
#  'almost': 933,
#  'hatred': 934,
#  'serious': 935,
#  "Bob's": 936,
#  'fledged': 937,
#  'http://t.co/KJjluCqBqr': 938,
#  '#JasonRezaian': 939,
#  'unravel': 940,
#  'ink.': 941,
#  'snakes': 942,
#  '@ThatsJustBogus:': 943,
#  '#WasntAbletoWatch': 944,
#  'liberal': 945,
#  'Bad': 946,
#  'model,': 947,
#  'tax': 948,
#  'Screw': 949,
#  'questions.': 950,
#  'Incensed': 951,
#  'https://t.co/S99LR4vbAG': 952,
#  'Johnny': 953,
#  'unfortunately': 954,
#  '@AnneBayefsky:': 955,
#  'slob.': 956,
#  'are:': 957,
#  '#GOPtbt': 958,
#  'Central': 959,
#  'Stronger.': 960,
#  'drug”': 961,
#  'bright': 962,
#  'NYT': 963,
#  'Seemed': 964,
#  '"Well': 965,
#  '@brainybug23:': 966,
#  'slide': 967,
#  'Kerry.': 968,
#  'Y’all': 969,
#  '#priorities': 970,
#  'please,': 971,
#  'Washington."': 972,
#  'real:': 973,
#  'explains': 974,
#  'scary...': 975,
#  "coach's": 976,
#  'Marco': 977,
#  'puppets.': 978,
#  'Independent!': 979,
#  'Trump,': 980,
#  'irrelevant!': 981,
#  'drawn': 982,
#  '#lastnight': 983,
#  'stomach': 984,
#  'says,': 985,
#  'language': 986,
#  'immigration"': 987,
#  'constitutional': 988,
#  '@edeweysmith:': 989,
#  'https://t.co/w1qvOWU2CB': 990,
#  'is...on': 991,
#  'the…': 992,
#  'win!': 993,
#  'bragged': 994,
#  'resonates': 995,
#  'succeed.': 996,
#  'champ': 997,
#  'Martin': 998,
#  '"race': 999,
#  ...}

# %%
# What is that set stuff....I had no clue!!!
# Method 2
text_df = pd.DataFrame({"words":word_list})
words = text_df['words'].unique()
counter=0
enc_brute2={}
dec_brute2={}
for i in words:
    enc_brute2[i] = counter
    dec_brute2[counter] = i
    counter = counter + 1

# %%
enc_brute2  #different order still, but makes some sense.
# Out:
# {'RT': 0,
#  '@NancyLeeGrahn:': 1,
#  'How': 2,
#  'did': 3,
#  'everyone': 4,
#  'feel': 5,
#  'about': 6,
#  'the': 7,
#  'Climate': 8,
#  'Change': 9,
#  'question': 10,
#  'last': 11,
#  'night?': 12,
#  'Exactly.': 13,
#  '#GOPDebate': 14,
#  '@ScottWalker:': 15,
#  "Didn't": 16,
#  'catch': 17,
#  'full': 18,
#  '#GOPdebate': 19,
#  'night.': 20,
#  'Here': 21,
#  'are': 22,
#  'some': 23,
#  'of': 24,
#  "Scott's": 25,
#  'best': 26,
#  'lines': 27,
#  'in': 28,
#  '90': 29,
#  'seconds.': 30,
#  '#Walker16': 31,
#  'http://t.co/ZSfF…': 32,
#  '@TJMShow:': 33,
#  'No': 34,
#  'mention': 35,
#  'Tamir': 36,
#  'Rice': 37,
#  'and': 38,
#  'was': 39,
#  'held': 40,
#  'Cleveland?': 41,
#  'Wow.': 42,
#  '@RobGeorge:': 43,
#  'That': 44,
#  'Carly': 45,
#  'Fiorina': 46,
#  'is': 47,
#  'trending': 48,
#  '--': 49,
#  'hours': 50,
#  'after': 51,
#  'HER': 52,
#  'debate': 53,
#  'above': 54,
#  'any': 55,
#  'men': 56,
#  'just-completed': 57,
#  'says': 58,
#  "she's": 59,
#  'on': 60,
#  '…': 61,
#  '@DanScavino:': 62,
#  'w/': 63,
#  '@realDonaldTrump': 64,
#  'delivered': 65,
#  'highest': 66,
#  'ratings': 67,
#  'history': 68,
#  'presidential': 69,
#  'debates.': 70,
#  '#Trump2016': 71,
#  'http://t.co…': 72,
#  '@GregAbbott_TX:': 73,
#  '@TedCruz:': 74,
#  '"On': 75,
#  'my': 76,
#  'first': 77,
#  'day': 78,
#  'I': 79,
#  'will': 80,
#  'rescind': 81,
#  'every': 82,
#  'illegal': 83,
#  'executive': 84,
#  'action': 85,
#  'taken': 86,
#  'by': 87,
#  'Barack': 88,
#  'Obama."': 89,
#  '@FoxNews': 90,
#  '@warriorwoman91:': 91,
#  'liked': 92,
#  'her': 93,
#  'happy': 94,
#  'when': 95,
#  'heard': 96,
#  'she': 97,
#  'going': 98,
#  'to': 99,
#  'be': 100,
#  'moderator.': 101,
#  'Not': 102,
#  'anymore.': 103,
#  '@megynkelly': 104,
#  'https://…': 105,
#  'Going': 106,
#  '#MSNBC': 107,
#  'Live': 108,
#  'with': 109,
#  '@ThomasARoberts': 110,
#  'around': 111,
#  '2': 112,
#  'PM': 113,
#  'ET.': 114,
#  'Deer': 115,
#  'headlights': 116,
#  '@lizzwinstead:': 117,
#  'Ben': 118,
#  'Carson,': 119,
#  'may': 120,
#  'only': 121,
#  'brain': 122,
#  'surgeon': 123,
#  'who': 124,
#  'has': 125,
#  'performed': 126,
#  'a': 127,
#  'lobotomy': 128,
#  'himself.': 129,
#  '@NancyOsborne180:': 130,
#  'Last': 131,
#  "night's": 132,
#  'proved': 133,
#  'it!': 134,
#  '#BATsAsk': 135,
#  '@BadassTeachersA': 136,
#  '#TBATs': 137,
#  'https://t.co/G2gGjY1bJD': 138,
#  '@JGreenDC': 139,
#  'In': 140,
#  'all': 141,
#  'fairness': 142,
#  '#BillClinton': 143,
#  'owns': 144,
#  'that': 145,
#  'phrase.#GOPDebate': 146,
#  '@WayneDupreeShow:': 147,
#  'Just': 148,
#  'woke': 149,
#  'up': 150,
#  'tweet': 151,
#  'this': 152,
#  'out': 153,
#  'Best': 154,
#  'line': 155,
#  'night': 156,
#  'via': 157,
#  '@GovMikeHuckabee': 158,
#  'http://t.co/6OV5hxHIcV': 159,
#  'Me': 160,
#  'reading': 161,
#  "family's": 162,
#  'comments': 163,
#  'how': 164,
#  'great': 165,
#  'http://t.co/gIaGjPygXZ': 166,
#  '@ArcticFox2016:': 167,
#  '@AllenWestRepub': 168,
#  '"Dear': 169,
#  '@JebBush': 170,
#  '#NotAMistake': 171,
#  'http://t.co/TtFG7KYcd9"': 172,
#  '@pattonoswalt:': 173,
#  'loved': 174,
#  'Scott': 175,
#  'Walker': 176,
#  'as': 177,
#  'Mark': 178,
#  "Harmon's": 179,
#  'romantic': 180,
#  'rival': 181,
#  'SUMMER': 182,
#  'SCHOOL.': 183,
#  'Look': 184,
#  'it': 185,
#  'up.': 186,
#  'Hey': 187,
#  '@ChrisChristie': 188,
#  'exploiting': 189,
#  'tragedy': 190,
#  '9/11': 191,
#  'for': 192,
#  'your': 193,
#  'own': 194,
#  'political': 195,
#  'gain': 196,
#  "@rudygiulianiGOP's": 197,
#  'thing': 198,
#  '@CarolCNN:': 199,
#  '#DonaldTrump': 200,
#  'under': 201,
#  'fire': 202,
#  'women': 203,
#  '@PeterBeinart': 204,
#  '@SL_Schaeffer': 205,
#  '@IWF': 206,
#  '@@MyRkiger': 207,
#  'weigh': 208,
#  'http://t.…': 209,
#  '@johncardillo:': 210,
#  'Guess': 211,
#  'had': 212,
#  'most': 213,
#  'speaking': 214,
#  'time': 215,
#  'at': 216,
#  '#GOPDebate.': 217,
#  'moderators': 218,
#  '31.7%': 219,
#  'time.': 220,
#  'http://t.co/2WSUT0c0Lx': 221,
#  'reason': 222,
#  'comment': 223,
#  'funny': 224,
#  "'in": 225,
#  'case': 226,
#  "you're": 227,
#  "ignorant'": 228,
#  '#gop': 229,
#  '#tcot': 230,
#  'government': 231,
#  "isn't": 232,
#  'working': 233,
#  'people': 234,
#  '#gopdebate': 235,
#  '@PamelaGeller:': 236,
#  'Huckabee:': 237,
#  'Paying': 238,
#  'transgender': 239,
#  'surgery': 240,
#  'soldiers,': 241,
#  'sailors': 242,
#  'airmen': 243,
#  'does': 244,
#  'not': 245,
#  'make': 246,
#  'our': 247,
#  'country': 248,
#  'safer': 249,
#  '#Ha': 250,
#  '@ChuckNellis:': 251,
#  'Cruz': 252,
#  'class': 253,
#  '&amp;': 254,
#  'truth,': 255,
#  'gets': 256,
#  'vote!': 257,
#  '@mchamric:': 258,
#  '“@TeaTraitors:': 259,
#  'still': 260,
#  'Clown': 261,
#  'Show!': 262,
#  "I'm": 263,
#  'glad': 264,
#  'Head': 265,
#  'Trump': 266,
#  'helping': 267,
#  'destroy': 268,
#  'GOP.': 269,
#  'http://t.co/nwGx8G8JWr”': 270,
#  '@erinmallorylong:': 271,
#  '*I*': 272,
#  'hate': 273,
#  'Planned': 274,
#  'Parenthood': 275,
#  'more!': 276,
#  'NO': 277,
#  'HATE': 278,
#  'PLANNED': 279,
#  'PARENTHOOD': 280,
#  'AND': 281,
#  'WOMEN': 282,
#  'MORE!!!!!': 283,
#  '@thekevinryder:': 284,
#  '(Vine': 285,
#  '@dabulldawg88)': 286,
#  'https://t.co/XKxVDrADce': 287,
#  '@MrPooni:': 288,
#  'Fox': 289,
#  'News': 290,
#  'trying': 291,
#  'convince': 292,
#  'us': 293,
#  'young': 294,
#  'Black': 295,
#  'Americans': 296,
#  'more': 297,
#  'worried': 298,
#  'ISIS': 299,
#  'than': 300,
#  'police': 301,
#  'terrorism': 302,
#  'http://t.co/…': 303,
#  'rankings:': 304,
#  'worst': 305,
#  'performance': 306,
#  '-': 307,
#  'Rubio,': 308,
#  'Kasich,': 309,
#  'Christie,': 310,
#  'Bush,': 311,
#  'Trump,': 312,
#  'Cruz,': 313,
#  'Walker,': 314,
#  'Paul,': 315,
#  'Huckabee,': 316,
#  'Carson.': 317,
#  '@TheBaxterBean:': 318,
#  "Walker's": 319,
#  'Abortion': 320,
#  'Ban': 321,
#  'Allows': 322,
#  'Rapist': 323,
#  'Father': 324,
#  'To': 325,
#  'Sue': 326,
#  'For': 327,
#  'Emotional': 328,
#  'Distress': 329,
#  'http://t.co/rHMvgumuir': 330,
#  '@Badger…': 331,
#  '@feministabulous:': 332,
#  "It's": 333,
#  'competition,': 334,
#  'but': 335,
#  'have': 336,
#  'we': 337,
#  'moved': 338,
#  'so': 339,
#  'far': 340,
#  'gay': 341,
#  'rights': 342,
#  "women's": 343,
#  'worse': 344,
#  "it's": 345,
#  'ever': 346,
#  'been?': 347,
#  '#G…': 348,
#  '@mch7576:': 349,
#  'http://t.co/pRy2QPCWfu””': 350,
#  '@HillaryClinton:': 351,
#  'Watch': 352,
#  '#GOPdebate?': 353,
#  'Bet': 354,
#  'you': 355,
#  'like': 356,
#  'donating': 357,
#  'Democrat': 358,
#  'right': 359,
#  'now.': 360,
#  'http://t.co/pGlQCqQgOP': 361,
#  'http://t.co/QP1e…': 362,
#  '@fbhw': 363,
#  "they're": 364,
#  'need': 365,
#  'borrow': 366,
#  'train': 367,
#  'horn': 368,
#  'next': 369,
#  '!': 370,
#  'The': 371,
#  'little': 372,
#  'bell': 373,
#  'wimpy!': 374,
#  '#hornmeansyouredone': 375,
#  '@LisaVikingstad:': 376,
#  'Ted': 377,
#  'bed.': 378,
#  'He': 379,
#  'keep': 380,
#  'confusingly': 381,
#  'sad': 382,
#  'look': 383,
#  'his': 384,
#  'face': 385,
#  'refuse': 386,
#  'First': 387,
#  '#GOPDebate:': 388,
#  'Social': 389,
#  'Media': 390,
#  'Reaction': 391,
#  'More': 392,
#  'http://t.co/X6KUVSkltF': 393,
#  '#SocialMedia:': 394,
#  'http://t.co/ogoYfNyiKj': 395,
#  'WinesdayPodcast': 396,
#  ':': 397,
#  'An': 398,
#  'update': 399,
#  'FoxNews': 400,
#  'tech': 401,
#  'failures': 402,
#  'http://t.co/FGGlf2J5HU': 403,
#  'http://t.co/Zw35DkUozi': 404,
#  '@AmyMek:': 405,
#  'Torched': 406,
#  'been': 407,
#  'passed': 408,
#  '-&gt;.@CandyCrowley': 409,
#  'no': 410,
#  'longer': 411,
#  'Famous': 412,
#  'Political': 413,
#  'Assassin!': 414,
#  'Congratulations': 415,
#  '@megynkelly,': 416,
#  'U': 417,
#  'Wi…': 418,
#  '@stockwizards3:': 419,
#  'Trump/Carson': 420,
#  'ticket': 421,
#  'would': 422,
#  'win': 423,
#  'landslide...': 424,
#  '@seanhannity': 425,
#  '@AnnCoulter': 426,
#  '#Republican': 427,
#  '#potus': 428,
#  '@kvxrdashian:': 429,
#  'Jeb': 430,
#  'Bush:': 431,
#  '"Obama': 432,
#  'fault,': 433,
#  'brother,': 434,
#  'because': 435,
#  'Obama': 436,
#  "didn't": 437,
#  'clean': 438,
#  'mess': 439,
#  'brother': 440,
#  'made."': 441,
#  'http://t…': 442,
#  '@ali:': 443,
#  'After': 444,
#  '#GOPDebate,': 445,
#  'primary': 446,
#  'voters': 447,
#  'none': 448,
#  'wiser': 449,
#  'policy': 450,
#  'plans': 451,
#  'these': 452,
#  'folks': 453,
#  'putting': 454,
#  'forth.': 455,
#  'Journalism': 456,
#  '@itsashlyperez:': 457,
#  'listening': 458,
#  'fetty': 459,
#  'wap': 460,
#  'while': 461,
#  'packing': 462,
#  "i'm": 463,
#  'true': 464,
#  'american': 465,
#  '#doesthishashtagexpire?': 466,
#  '@mgell:': 467,
#  'cross': 468,
#  'between': 469,
#  'shrug': 470,
#  'emoji': 471,
#  'President': 472,
#  'Business': 473,
#  'from': 474,
#  'Lego': 475,
#  'movie.': 476,
#  '@JamelleMyBelle:': 477,
#  'Meanwhile,': 478,
#  'White': 479,
#  'House...': 480,
#  'http://t.co/nouUUt5hKq': 481,
#  '@RowdyGentleman:': 482,
#  'If': 483,
#  'you’re': 484,
#  'planning': 485,
#  'drinking': 486,
#  'game': 487,
#  'now,': 488,
#  'Rowdy': 489,
#  'Gentleman.': 490,
#  '@brownblaze:': 491,
#  'PLEASE': 492,
#  'RT.': 493,
#  '#KKKorGOP': 494,
#  'http://t.co/YaqYAC3uV3': 495,
#  'thinks': 496,
#  'criticism': 497,
#  'misogynistic': 498,
#  'remarks': 499,
#  '"political': 500,
#  'correctness"': 501,
#  'problem.': 502,
#  'Nope,': 503,
#  'pervasive': 504,
#  '#sexism': 505,
#  '@LeKarmaSucre:': 506,
#  'handled': 507,
#  '#BlackLivesMatter': 508,
#  'http://t.co/8ZGdY6lPCT': 509,
#  '@palmaceiahome1:': 510,
#  'goal': 511,
#  '#FoxNews': 512,
#  'take': 513,
#  'pave': 514,
#  'way': 515,
#  'RINO': 516,
#  'Bush': 517,
#  'or': 518,
#  'Kasich.': 519,
#  '@philstockworld:': 520,
#  'From': 521,
#  'Chat': 522,
#  'Room:': 523,
#  '#Trump': 524,
#  '#Futures': 525,
#  '$SPY': 526,
#  '#NonFarmPayrolls': 527,
#  '#Jobs': 528,
#  '#Netflix': 529,
#  'http://t.co/0K06Sf81rq': 530,
#  'http…': 531,
#  '“@DanScavino:': 532,
#  'say': 533,
#  'thanks': 534,
#  '@gov:': 535,
#  'Most-Tweeted': 536,
#  'moment:': 537,
#  'saying': 538,
#  'purpose': 539,
#  'military': 540,
#  '"to': 541,
#  'kill': 542,
#  'people/break': 543,
#  'things"': 544,
#  're': 545,
#  'trans': 546,
#  'servicemembers': 547,
#  '@ariannahuff:': 548,
#  'http://t.co/YkI30j7hhO': 549,
#  '@megynkelly:': 550,
#  '.@ChrisStirewalt:': 551,
#  'Big': 552,
#  'moments': 553,
#  'were': 554,
#  '@RandPaul': 555,
#  'vs.': 556,
#  '@ChrisChristie,': 557,
#  'reaction': 558,
#  'question.': 559,
#  '#KellyFil…': 560,
#  '@STYLEMOM:': 561,
#  "Here's": 562,
#  'question,': 563,
#  'WHY': 564,
#  'hell': 565,
#  'body': 566,
#  'parts': 567,
#  'even': 568,
#  'debate?': 569,
#  'Foh,': 570,
#  'stop': 571,
#  'it,': 572,
#  '1965': 573,
#  'wtf': 574,
#  '#GOPDebate…': 575,
#  '@rushlimbaugh': 576,
#  'getting': 577,
#  'beheaded': 578,
#  'overseas': 579,
#  'whether': 580,
#  'calls': 581,
#  'Rosie': 582,
#  "O'Donnell": 583,
#  'fat?': 584,
#  "won't": 585,
#  'defend': 586,
#  '@FoxNews,': 587,
#  'they': 588,
#  'FAR': 589,
#  'fair': 590,
#  'OR': 591,
#  'balanced': 592,
#  'night,': 593,
#  'name': 594,
#  'calling': 595,
#  'juvenile.': 596,
#  '@theskysgoneout:': 597,
#  'non-Christians,': 598,
#  '"God"': 599,
#  'questions': 600,
#  'underline': 601,
#  'anyone': 602,
#  'really': 603,
#  'cares': 604,
#  'religious': 605,
#  'minorities.': 606,
#  'Chri…': 607,
#  '@Bipartisanism:': 608,
#  'response': 609,
#  'pathetic.': 610,
#  'http://t.co/isMXbrRM0h': 611,
#  '@factcheckdotorg:': 612,
#  '.@JebBush': 613,
#  'said': 614,
#  'he': 615,
#  'cut': 616,
#  'FL': 617,
#  'taxes': 618,
#  '$19B.': 619,
#  'But': 620,
#  'includes': 621,
#  'cuts': 622,
#  'estate': 623,
#  'mandated': 624,
#  'federal': 625,
#  'law.': 626,
#  'ht…': 627,
#  '@mydaughtersarmy:': 628,
#  'Dear': 629,
#  'GOP,': 630,
#  'want': 631,
#  'abortions...': 632,
#  'http://t.co/RbL1t4iPx6': 633,
#  '@KarrattiPaul:': 634,
#  'Join': 635,
#  'sign': 636,
#  'death': 637,
#  'warrant,': 638,
#  'Signed': 639,
#  '@tedcruz': 640,
#  'US\U000fe4e6': 641,
#  '#WakeUpAmerica': 642,
#  '#CruzCrew': 643,
#  'htt…': 644,
#  '@P0TUS:': 645,
#  'closing': 646,
#  'statements:': 647,
#  'http://t.co/S15NLilLso': 648,
#  'Status': 649,
#  '👉': 650,
#  'Single': 651,
#  'broke': 652,
#  'night!': 653,
#  'Goodbye': 654,
#  '@BretBaier': 655,
#  'Chris': 656,
#  'Wallace.': 657,
#  '@FrankLuntz:': 658,
#  'Before': 659,
#  '14': 660,
#  'focus': 661,
#  'groupers': 662,
#  'favorable': 663,
#  'view': 664,
#  'Trump.': 665,
#  'After,': 666,
#  '3': 667,
#  'saw': 668,
#  'him': 669,
#  'positively.': 670,
#  'http://…': 671,
#  '@_Holly_Renee:': 672,
#  'made': 673,
#  'donation': 674,
#  '@CarlyFiorina.': 675,
#  'So': 676,
#  'impressed': 677,
#  'performance.': 678,
#  '#Fiorina': 679,
#  'http://t.co/JLfhFvZ7ST': 680,
#  '@TheJimHughes:': 681,
#  'sending': 682,
#  'foreign': 683,
#  'aid': 684,
#  'places': 685,
#  'burn': 686,
#  'flag': 687,
#  'can': 688,
#  'start': 689,
#  'Berkeley?': 690,
#  '@frankthorpNBC:': 691,
#  'Rand': 692,
#  'Paul': 693,
#  'eye': 694,
#  'roll': 695,
#  'Christie': 696,
#  'https://t.co/hf318QSoWD': 697,
#  '@JohnKasich:': 698,
#  'Scrap': 699,
#  "President's": 700,
#  'Iran': 701,
#  'deal.': 702,
#  'can’t': 703,
#  'get': 704,
#  'nuke.': 705,
#  '#Kasich4Us': 706,
#  'http://t.co/9TrZxOnLZF': 707,
#  'Trying': 708,
#  'decide': 709,
#  'if': 710,
#  'too': 711,
#  'early': 712,
#  'come': 713,
#  'back': 714,
#  'Twitter': 715,
#  'fulltime.': 716,
#  'Was': 717,
#  'gonna': 718,
#  'wait': 719,
#  'closer': 720,
#  'election': 721,
#  'me': 722,
#  'hooked': 723,
#  '@MsPackyetti:': 724,
#  'Donald': 725,
#  "Trump's": 726,
#  'campaign': 727,
#  'reveals': 728,
#  '1': 729,
#  'important': 730,
#  'thing:': 731,
#  'Trolls': 732,
#  'real': 733,
#  'people.': 734,
#  'And': 735,
#  'vote.': 736,
#  'should': 737,
#  'scare': 738,
#  'eve…': 739,
#  'Those': 740,
#  '"don\'t': 741,
#  'worry,': 742,
#  'NEVER': 743,
#  'elected"': 744,
#  'remember': 745,
#  'elected': 746,
#  'George': 747,
#  'Bush.': 748,
#  'Twice.': 749,
#  'http:…': 750,
#  'Had': 751,
#  'Its': 752,
#  'Own': 753,
#  'Agenda:': 754,
#  'Promote': 755,
#  '"never': 756,
#  'fired': 757,
#  'HP"': 758,
#  'Fiorina,': 759,
#  'run': 760,
#  'race': 761,
#  'http://t.co/9k1eujdFo7': 762,
#  '@HlLLARY:': 763,
#  'Oh,': 764,
#  'one': 765,
#  'thing.': 766,
#  'Did': 767,
#  'hear': 768,
#  'anything': 769,
#  'affordable': 770,
#  'child': 771,
#  'care': 772,
#  'families': 773,
#  '?': 774,
#  'I…': 775,
#  '@NaughtyBeyotch:': 776,
#  'http://t.co/WQnSuPSPkC"': 777,
#  '@marthamaccallum': 778,
#  '@billhemmer': 779,
#  'Bill': 780,
#  'Martha': 781,
#  'A': 782,
#  'Team': 783,
#  'debate.': 784,
#  '2nd': 785,
#  'an': 786,
#  'ambush.': 787,
#  "Country's": 788,
#  'Megyn': 789,
#  'Kelly': 790,
#  'attacking': 791,
#  '"war': 792,
#  'women?"': 793,
#  '@Franklin_Graham:': 794,
#  '1st': 795,
#  '#GOPDebate--Encouraging': 796,
#  'see': 797,
#  'several': 798,
#  'candidates': 799,
#  'express': 800,
#  'their': 801,
#  'faith': 802,
#  'God': 803,
#  'His': 804,
#  'Son,': 805,
#  'Jesus': 806,
#  'Christ.': 807,
#  'http://t.c…': 808,
#  '@SnarkyDemo:': 809,
#  'he’s': 810,
#  '“politically': 811,
#  'correct.”': 812,
#  'Which,': 813,
#  'course,': 814,
#  'Trumpspeak': 815,
#  '“Let’s': 816,
#  'I’m': 817,
#  'huge': 818,
#  'asshole.”': 819,
#  '#…': 820,
#  'message': 821,
#  'candidates:': 822,
#  'http://t.co/WFK5CmVgiN': 823,
#  '@davidcicilline:': 824,
#  'This': 825,
#  'episode': 826,
#  'Apprentice': 827,
#  "I've": 828,
#  'seen.': 829,
#  '@GovMikeHuckabee:': 830,
#  'Luntz:': 831,
#  '"As': 832,
#  'go': 833,
#  'up,': 834,
#  'almost': 835,
#  'reach': 836,
#  '100.': 837,
#  'It': 838,
#  'never': 839,
#  'happens': 840,
#  'dial': 841,
#  'research': 842,
#  'do."': 843,
#  '@lolhayley:': 844,
#  '"The': 845,
#  'break': 846,
#  'things."': 847,
#  'something': 848,
#  'actual': 849,
#  'man': 850,
#  'running': 851,
#  'president': 852,
#  'just': 853,
#  'Wondering': 854,
#  'could': 855,
#  'Republican': 856,
#  'Party': 857,
#  'pay': 858,
#  'liver': 859,
#  'transplant': 860,
#  'playing': 861,
#  '@mtaibbi': 862,
#  '@BrandonDHowell:': 863,
#  'Great': 864,
#  'Friday.': 865,
#  '#CarlyFiorina': 866,
#  '@CarlyFiorina': 867,
#  'http://t.co/1ai9CuZ8bY': 868,
#  '@tedcruz:': 869,
#  'elected,': 870,
#  'President,': 871,
#  "I'll": 872,
#  'unconstitutional': 873,
#  'order': 874,
#  'enacted': 875,
#  'Pres.': 876,
#  'Oba…': 877,
#  '@Ronnie2K:': 878,
#  'during': 879,
#  'like...': 880,
#  'https://t.co/jCUirk1i1u': 881,
#  '@bruneski:': 882,
#  'upstairs': 883,
#  'kids': 884,
#  'many': 885,
#  'climate': 886,
#  'change': 887,
#  'miss?': 888,
#  '#GOPClownCar': 889,
#  'They’re': 890,
#  'Todd': 891,
#  'Akin': 892,
#  'now:': 893,
#  'sting': 894,
#  'backfired': 895,
#  'Republicans': 896,
#  '#StandwithPP': 897,
#  'http://t.co/ekXPfKtHQn': 898,
#  '@learjetter:': 899,
#  '@Foxnews': 900,
#  'let': 901,
#  '#REPUBLICANS': 902,
#  'digest': 903,
#  'before': 904,
#  'allowing': 905,
#  'crazy': 906,
#  '@DWStweets': 907,
#  'TRASH': 908,
#  'OUR': 909,
#  '#GOP!': 910,
#  '@LadySandersfarm': 911,
#  'http:/…': 912,
#  'Receive': 913,
#  'Enormous': 914,
#  'Applause': 915,
#  'Horribly': 916,
#  'Misogynistic': 917,
#  'Answer': 918,
#  'http://t.co/R4e8TpOtd5': 919,
#  'few': 920,
#  'favorite': 921,
#  '#Twitter': 922,
#  'responses': 923,
#  'night:': 924,
#  'http://t.co/2IqcdrCdlm': 925,
#  'http://t.co/7TDMA3VLM8': 926,
#  'Even': 927,
#  'though': 928,
#  'super': 929,
#  'conservative': 930,
#  'reporter,': 931,
#  'actually': 932,
#  "Kelly's": 933,
#  'interview': 934,
#  'style': 935,
#  '@kingsthings:': 936,
#  'all.': 937,
#  'series': 938,
#  'minute': 939,
#  'opportunities': 940,
#  'avoid': 941,
#  'answering': 942,
#  'candidate…': 943,
#  '@MelissaGracey:': 944,
#  'Credit': 945,
#  'joke': 946,
#  'goes': 947,
#  'someone': 948,
#  'else': 949,
#  'funny!': 950,
#  'http://t.co/iCreDSSplR': 951,
#  '@Reince:': 952,
#  'Simply': 953,
#  'incredible.': 954,
#  'http://t.co/apXM8AO8jf': 955,
#  'doubled': 956,
#  'previous': 957,
#  'record': 958,
#  'most-watched': 959,
#  'i…': 960,
#  '@KateThomas:': 961,
#  'literally': 962,
#  "couldn't": 963,
#  'me.': 964,
#  '"I': 965,
#  'Watched': 966,
#  'All': 967,
#  'Got': 968,
#  'Lousy': 969,
#  'Hangover"': 970,
#  'http://t.co/cxch7X…': 971,
#  '@fl_dreamer:': 972,
#  'Haha': 973,
#  'saas': 974,
#  '@voxdotcom': 975,
#  'morning': 976,
#  'towards': 977,
#  '@realDonaldTrump.': 978,
#  '#FactChecked': 979,
#  'http://t.co/dAeCtmLlaj': 980,
#  '@TexasCruzn:': 981,
#  'http://t.co/1z3VuFjZlw"': 982,
#  '@zellieimani:': 983,
#  'What': 984,
#  'person': 985,
#  'vs': 986,
#  'what': 987,
#  'tv.': 988,
#  'http://t.co/QlGsXRH5Hw': 989,
#  'Marco': 990,
#  'Rubio': 991,
#  'Told': 992,
#  'Face': 993,
#  "He's": 994,
#  "'Candidate": 995,
#  'Of': 996,
#  "Yesterday'": 997,
#  'Anti-Gay': 998,
#  'Bigotry': 999,
#  ...}

# %% [markdown]
# Now I need to shift my padding to account for the '<pad>' and '<start>' tokens.  I also need to account for that in my decoders.  If you chose to use one of the other decoders, they need to be shifted as well.
#
# Decoder doesn't need shifting, just a map of the proper number.  Since all the words are off by 2 in the encoder, we can subtract 2 from the encoder result to get the decoder key.  However, entries -1 and -2 are not in the decoder, so I need to add them in.  <i> This is why I got goofy results on Tuesday night as I did the deocder wrong when I tried to switch back to text. </i>

# %%
for i in enc:
    enc[i] = enc[i]+2

# %%
enc['pad']=0
enc['<start>']=1
dec[-2]='pad'
dec[-1]='<start>'

# %% [markdown]
# ### Make some numbers
# For each tweet, split up the tweet into words, look up each word in the encoder (line 4,15).  Then append it to a list(line 5, 16).  Finally take the target and encode it 1 for positive and 0 for negative

# %%
x_train=[]
y_train=[]
for i in range(train.shape[0]):
    tmp = [enc[j] for j in train.iloc[i,15].split()]
    x_train.append(tmp)
    if train.iloc[i,5]=='Positive':
        y=1
    else:
        y=0
    y_train.append(y)
    
x_test=[]
y_test=[]
for i in range(test.shape[0]):
    tmp = [enc[j] for j in test.iloc[i,15].split()]
    x_test.append(tmp)
    if test.iloc[i,5]=='Positive':
        y=1
    else:
        y=0
    y_test.append(y)

# %% [markdown]
# I now have several lists of list (a list, where the list elements are lists)
#
# Lets try and find a good sequence length.  In this case, everything was 29 tokens or less.

# %%
print(max([len(i) for i in x_train]))
print(max([len(i) for i in x_test]))
# Out:
# 29
# 27

# %% [markdown]
# Lets make sure Dr. Nutjob did his encoding correctly.

# %%
tmp = [enc[j] for j in train.iloc[0,15].split()]
tmp
# Out:
# [2,
#  2654,
#  1238,
#  2397,
#  3,
#  662,
#  87,
#  33,
#  229,
#  1344,
#  34,
#  240,
#  7,
#  6864,
#  239,
#  1487,
#  13,
#  2655,
#  2656,
#  976,
#  11404]

# %%
train.iloc[0,15]  #original tweet
# Out:
# "RT @ScottWalker: Didn't catch the full #GOPdebate last night. Here are some of Scott's best lines in 90 seconds. #Walker16 http://t.co/ZSfF…"

# %%
[dec[i-2] for i in tmp]  #remember that the decoder was not shifted, so i need to subtract 2 to get the correct word
# Out:
# ['RT',
#  '@ScottWalker:',
#  "Didn't",
#  'catch',
#  'the',
#  'full',
#  '#GOPdebate',
#  'last',
#  'night.',
#  'Here',
#  'are',
#  'some',
#  'of',
#  "Scott's",
#  'best',
#  'lines',
#  'in',
#  '90',
#  'seconds.',
#  '#Walker16',
#  'http://t.co/ZSfF…']

# %% [markdown]
# How would we do this if we had really long tweet lengths?
#
# Plot a histogram and get an idea of where most of the data lies

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist([len(i) for i in x_train],bins=100)
plt.show()

# %%
import scipy
lengths = [len(i) for i in x_train]
print(scipy.quantile(lengths,0.85)) #what value contains 85% of my training data (i didnt add test data)
print(scipy.quantile(lengths,0.90)) # 90%
print(scipy.quantile(lengths,0.95)) # 95%
print(scipy.quantile(lengths,0.99)) # 99%
# Out:
# 23.0
# 24.0
# 25.0
# 27.0

# %% [markdown]
# Remember the IMDB dataset, that is a good example of how to pick a cutoff.  We plot the histogram and find quantiles and see that more than 90% of  our data is less than 500 tokens.  My personal choice may have been to do 600 vs 500 as its the 95% quantile, but hey, I'm just a (adjunct) professor of data science.

# %%
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
(X_train_imdb, y_train_imdb), (X_test_imdb, y_test_imdb) = imdb.load_data(num_words=5000)

# %%
lengths_imdb = [len(i) for i in X_train_imdb]
lengths_imdb = lengths_imdb + [len(i) for i in X_test_imdb]


print(scipy.quantile(lengths_imdb,0.85)) #what value contains 85% of my training data (i didnt add test data)
print(scipy.quantile(lengths_imdb,0.90)) # 90%
print(scipy.quantile(lengths_imdb,0.95)) # 95%
print(scipy.quantile(lengths_imdb,0.99)) # 99%

plt.hist(lengths_imdb,bins=2000)
# Out:
# 378.0
# 457.0
# 598.0
# 914.0
# (array([2., 1., 2., ..., 0., 0., 1.]),
#  array([   7.    ,    8.2435,    9.487 , ..., 2491.513 , 2492.7565,
#         2494.    ]),
#  <a list of 2000 Patch objects>)

# %% [markdown]
# Ok now i need to add my start token and then pad sequences to be 30 (29+1 start token) tokens long, equal to my longest sequence

# %%
x_train=[[1]+i for i in x_train]
x_test=[[1]+i for i in x_test]

# %%
from keras.preprocessing import sequence

max_words = 30
x_train = sequence.pad_sequences(x_train, maxlen=max_words)
x_test = sequence.pad_sequences(x_test, maxlen=max_words)

# %% [markdown]
# Only Arrays are allowed from here on out.  If only there was an easy way to make a list into an array....

# %%
x_train=np.asarray(x_train)
x_test=np.asarray(x_test)
y_train=np.asarray(y_train)
y_test=np.asarray(y_test)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"

# %%
import tensorflow as tf
sess_cpu = tf.Session(config=tf.ConfigProto(device_count={'GPU': 0}))

# %% [markdown]
# Borrowing from our previous code, lets shove this into a simple LSTM.  Embed each word to 100 dimensions, input length is max_words (30). I changed to vanilla LSTM to add dropout (regularizaion is our friend!) so I lose some speed, but this is a short example.  Not that we start to overfit and epoch 5.  Needs tuning but we have a good first exercise.

# %%
x_a, x_b, x_c = np.array_split(x_train, 3)

y_i, y_j, y_k = np.array_split(y_train, 3)

xt_a, xt_b, xt_c = np.array_split(x_test, 3)

yt_i, yt_j, yt_k = np.array_split(y_test, 3)

# %%
import keras
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import  LSTM, SimpleRNN, GRU
#from keras.layers import LSTM , SimpleRNN, GRU
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
# create the model
embedding_vecor_length = 100
model1 = Sequential()
top_words = len(enc)
model1.add(Embedding(top_words, embedding_vecor_length, input_length=max_words))
model1.add(LSTM(100,recurrent_dropout=0.2))
model1.add(Dense(1, activation='sigmoid'))
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model1.summary())
model1.fit(x_a, y_i, validation_data=(xt_a, yt_i), epochs=10, batch_size=64)

#
# Out:
# WARNING:tensorflow:From D:\Codeland\Anaconda2\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Codeland\Anaconda2\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 30, 100)           3165800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 3,246,301
# Trainable params: 3,246,301
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From D:\Codeland\Anaconda2\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2624 samples, validate on 953 samples
# Epoch 1/10
# 2624/2624 [==============================] - 6s 2ms/step - loss: 0.5588 - acc: 0.7828 - val_loss: 0.4433 - val_acc: 0.8499
# Epoch 2/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.3958 - acc: 0.8255 - val_loss: 0.4999 - val_acc: 0.7891
# Epoch 3/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.1332 - acc: 0.9611 - val_loss: 0.6023 - val_acc: 0.8374
# Epoch 4/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.0429 - acc: 0.9905 - val_loss: 0.6989 - val_acc: 0.8300
# Epoch 5/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.0203 - acc: 0.9939 - val_loss: 0.9217 - val_acc: 0.7807
# Epoch 6/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.0157 - acc: 0.9954 - val_loss: 0.7105 - val_acc: 0.8300
# Epoch 7/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.0149 - acc: 0.9962 - val_loss: 0.8590 - val_acc: 0.8300
# Epoch 8/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.0110 - acc: 0.9981 - val_loss: 1.0029 - val_acc: 0.8332
# Epoch 9/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.0065 - acc: 0.9985 - val_loss: 0.8909 - val_acc: 0.8185
# Epoch 10/10
# 2624/2624 [==============================] - 4s 1ms/step - loss: 0.0060 - acc: 0.9985 - val_loss: 1.0242 - val_acc: 0.8017

# %%
X_train[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-691b4934c597> in <module>
# ----> 1 X_train[0]
#
# NameError: name 'X_train' is not defined
