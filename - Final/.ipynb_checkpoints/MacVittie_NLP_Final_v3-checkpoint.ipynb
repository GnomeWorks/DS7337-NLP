# %%
from bs4 import BeautifulSoup, SoupStrainer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.manifold import TSNE

from nltk import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import LancasterStemmer

import re
import requests

import pandas as pd
import seaborn as sn
import numpy as np

import matplotlib.pyplot as plt

# %%
nltk.download('punkt')

# %%
# first, set up our movie review urls
# movie list is my top 10 + honorable mention: https://www.imdb.com/list/ls050974899/

review_urls = {
    'last_night': 'https://www.imdb.com/title/tt1294688/reviews?ref_=tt_urv',
    'vanilla_sky': 'https://www.imdb.com/title/tt0259711/reviews?ref_=tt_urv',
    'lost_in_translation': 'https://www.imdb.com/title/tt0335266/reviews?ref_=tt_urv',
    'never_let_me_go': 'https://www.imdb.com/title/tt1334260/reviews?ref_=tt_urv',
    'gattaca': 'https://www.imdb.com/title/tt0119177/reviews?ref_=tt_urv',
    'american_beauty': 'https://www.imdb.com/title/tt0169547/reviews?ref_=tt_urv',
    'megamind': 'https://www.imdb.com/title/tt1001526/reviews?ref_=tt_urv',
    'man_from_earth': 'https://www.imdb.com/title/tt0756683/reviews?ref_=tt_urv',
    'another_earth': 'https://www.imdb.com/title/tt1549572/reviews?ref_=tt_urv',
    'timer': 'https://www.imdb.com/title/tt1179794/reviews?ref_=tt_urv',
    '310_to_yuma': 'https://www.imdb.com/title/tt0381849/reviews?ref_=tt_urv',
}

# %%
stop_list = []

# %%
def get_txt(url):
    return requests.get(url).text


def get_links_from(html):
    tags = BeautifulSoup(html, 'html.parser', parse_only=SoupStrainer('a', href=True))
    urls = [str(tag.attrs['href']) for tag in tags]
    return urls


def get_review_urls(links):
    url_template = 'https://www.imdb.com{}'
    return [url_template.format(link) for link in links]


def link(link):
    if '/review/' in link:
        return True
    return False


def get_links(links):
    links = filter(link, links)
    unique_links = set(links)
    return list(unique_links)


def strain(name, attrs):
    if name == 'div' and dict(attrs).get('class', None) == 'content':
        return True
    return False


def clean_txt(text):
    return re.split('\\n\\n\s+\d+ out of \d+', text)[0]


def get_review_from_url(url):
    html = get_txt(url)
    tags = BeautifulSoup(html, 'html.parser', parse_only=SoupStrainer(strain))
    review = clean_txt(tags.text)
    return review


def get_review_from_site(url):
    reviews = []

    reviews_home_text = get_txt(url)
    all_links = get_links_from(reviews_home_text)
    links = get_links(all_links)

    review_urls = get_review_urls(links)
    for url in review_urls:
        reviews.append(get_review_from_url(url))
    return reviews


def get_reviews_from_all_sites(url_list):
    all_reviews = []
    review_titles = url_list.keys()
    for title in review_titles:
        review_url = review_urls[title]
        all_reviews = all_reviews + get_review_from_site(review_url)
    return all_reviews


def sentences_to_words(sentences):
    return [word_tokenize(s) for s in sentences]


def alphanumerize(words):
    regex_matcher = '^[a-zA-Z0-9]+$'
    return [w for w in words if re.match(regex_matcher, w)]


def lemmatize_word(word):
    stemmer = LancasterStemmer()
    lemma_word = stemmer.stem(word)
    if wordnet.synsets(lemma_word):
        return lemma_word
    else:
        return word    
    
    
def lemmatize_words(words):
    return [lemmatize_word(w) for w in words]


def remove_stops(words):
    return [w for w in words if w not in stop_words]


def preprocess_documents(docs):
    d_format_words = [d.lower().strip() for d in docs]
    docs_of_words = sentences_to_words(d_format_words)
    words_with_chars = [remove_stops(w) for w in docs_of_words]
    content_words = [alphanumerize(c) for c in words_with_chars]
    lemmatized = [lemmatize_words(w) for w in content_words]
    return lemmatized 


def topics_to_map(model, feature_names, no_top_words):
    map = []
    for topic_idx, topic in enumerate(model.components_):
        s = " ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])
        map.append(s)
    return map


def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic {}:".format(topic_idx), end=' ')
        stuff = " ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])
        print (stuff)

# %%
review_urls.values()
# Out:
# dict_values(['https://www.imdb.com/title/tt1294688/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt0259711/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt0335266/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt1334260/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt0119177/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt0169547/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt1001526/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt0756683/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt1549572/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt1179794/reviews?ref_=tt_urv', 'https://www.imdb.com/title/tt0381849/reviews?ref_=tt_urv'])

# %%
all_reviews = get_reviews_from_all_sites(review_urls)

# %%
# removing: movie titles; act(or/ress) names; director names; character names; misspellings of names; country names; 
#      non-English names of films; other proper names (studios, fictional characters, etc)
custom_stop_words = [ 'last', 'night', 'vanilla', 'sky', 'lost', 'in', 'translation', 'gattaca', 'american', 'beauty', 
                     'megamind', 'the', 'man', 'from', 'earth', 'another', 'timer', 'to', 'yuma', 'keira', 'knightley', 
                     'sam', 'worthington', 'eva', 'mendes', 'guillaume', 'canet', 'cameron', 'crowe', 'tom', 'cruise', 
                     'penelope', 'cruz', 'cameron', 'diaz', 'kurt', 'russell', 'sofia', 'coppola', 'bill', 'murray', 
                     'scarlett', 'johansson', 'giovanni', 'ribisi', 'anna', 'faris', 'mark', 'romanek', 'carey', 
                     'mulligan', 'andrew', 'garfield', 'izzy', 'meikle-small', 'andrew', 'niccol', 'ethan', 'hawke', 
                     'uma', 'thurman', 'jude', 'law', 'gore', 'vidal', 'kevin', 'spacey', 'annette', 'bening', 'thora', 
                     'birch', 'wes', 'bentley', 'tom', 'mcgrath', 'will', 'ferrell', 'jonah', 'hill', 'brad', 'pitt',
                     'tina', 'fey', 'richard', 'schenkman', 'david', 'lee', 'smith', 'tony', 'todd', 'john', 'billingsley', 
                     'ellen', 'crawford', 'mike', 'cahill', 'brit', 'marling', 'william', 'mapother', 'matthew-lee', 
                     'erlbach', 'DJ', 'flava', 'jac', 'schaeffer', 'emma', 'caulfield', 'ford', 'scott', 'holroyd', 'kali', 
                     'rocha', 'katherine', 'von', 'till', 'james', 'mangold', 'russell', 'crowe', 'christian', 'bale', 
                     'ben', 'foster', 'logan', 'lerman', 'joana', 'joanna', 'michael', 'laura', 'alex', 'lester', 'ricky', 
                     'jan', 'carolyn', 'vincent', 'jerome', 'eugene', 'farrell', 'bob', 'charlotte', 'japan', 'los', 
                     'obre', 'ajos', 'tommy', 'ruth', 'cathy', 'roxanne', 'metro', 'steph', 'mikey', 'amedori', 'michelle', 
                     'dreamworks', 'superman', 'dan', 'patrick', 'never', 'let', 'me', 'go' ]

stop_words = custom_stop_words + stopwords.words('english')

# %%
docs_of_words = preprocess_documents(all_reviews)

# %%
word_list = [w for d in docs_of_words for w in d]
len(word_list)
# Out:
# 41538

# %%
len(set(list_of_all_words))
# Out:
# 6085

# %%
flat_docs = [' '.join(d) for d in docs_of_words]

# %%
# Settings
NUM_FEATURES = 1600
NUM_TOPICS   = 20
NUM_WORDS    = 15

# %%
tf_vectorizer = TfidfVectorizer(max_features=NUM_FEATURES)
tf = tf_vectorizer.fit_transform(flat_docs)
tf_features = tf_vectorizer.get_feature_names()

# %%
nmf = NMF(n_components=NUM_TOPICS, random_state=1, alpha=.1, l1_ratio=.4, init='nndsvd').fit(tf)

# %%
nmf_topic_map = topics_to_map(nmf, tf_features, NUM_WORDS)
display_topics(nmf, tf_features, NUM_WORDS)
# Out:
# Topic 0: on real movie like ev think film would people life act time love way us
# Topic 1: film watch story effect best see mak direct fiction writ truly recommend characters top seen
# Topic 2: oona implanted timers love father soulmate rom borth meet true future wrist moth wear harrington
# Topic 3: wad western gang guy good gun bad outlaw son town ev char ranch shoot train
# Topic 4: oona end boyfriend zero forced treated beat quirky removed root cool build spent fantasy chemistry
# Topic 5: rhoda planet mirror family killed car contest burroughs four accident released mit williams sundance house
# Topic 6: genet society science future fiction discrimination engineering id world effect valid subtle dream perfect view
# Topic 7: villain animation superhero animated kid 3d sup good enjoy bad despicable hero laugh also popular
# Topic 8: jan angel suvari cheerlead burnham inst something fit ball men best 1999 daughter obvious allison
# Topic 9: origin abre ojos remake bet still good tries quality story song end executed bit build
# Topic 10: sweet love sour life span saw known chang way appreciate mad lot consequences prefer theme
# Topic 11: book read adapt sad heard ishiguro kathy intrigued kid scene science left novel kazuo hailsham
# Topic 12: tempt marry husband couple cheat infidel attract truly women reed simple get amazing day wife
# Topic 13: imagination terrible lazy imagine leaving end audience writ bet want us movie family fan fantast
# Topic 14: soul comedy count mat rom concept meet side everyone wo main countdown want start tells
# Topic 15: great best perform oscar awesome western on job direct entertain engross loved definitely bring worthy
# Topic 16: abre ojos miss origin july earn desperately curious perform tried kept opinion first born sweet
# Topic 17: desire emotion sign favourite soft relationships subtle opinion intense confused pick feel wo pay quiet
# Topic 18: movie watch good act like story seen movies always felt best concept enjoy amazing mind
# Topic 19: rat movie masterpiece greater themes excel imdb awful genius interest ok av mindless idiot screenplay

# %%
lda = LatentDirichletAllocation(n_topics=NUM_TOPICS, max_iter=50, learning_method='online', 
                                learning_offset=50.,random_state=0).fit(tf)
# Out:
# D:\Codeland\Anaconda2\lib\site-packages\sklearn\decomposition\online_lda.py:314: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %%
display_topics(lda, tf_features, NUM_WORDS)
# Out:
# Topic 0: remain film lust completely scenes ev may eq able seen open leaves show combined mix
# Topic 1: wad movie stagecoach watch mcelroy gang oona believe film ev mak town love people on
# Topic 2: film mod mast star environ whether raise love gift point cent tell bunch smaller put
# Topic 3: film root risk return sex fantasy ex dislike el term mean relatively everything interact photograph
# Topic 4: just 20 giving minutes team scenario bullet killer natural av sent ok rang coop killed
# Topic 5: rest entertain vary necessary show farm count loser on willing young fun un slight recent
# Topic 6: mat standard problem surviving spirit explored became cloth col way satire risk doubt interpret cent
# Topic 7: film movie put story great animated look on fan part mak el shoot two also
# Topic 8: at think movie young love since city aspect title meant est story considered explore characters
# Topic 9: film guy drag on movie ok takes worst seen undoubtedly time part bad throughout would
# Topic 10: killer shoot gut gang vet guy good bad money war get rid decides shot act
# Topic 11: apart remain regret haunt want love pot photograph film spend broken everyone stay discrimination subtle
# Topic 12: fashion loving kills nowadays much anyway beyond homophobic kept simply indeed jokes america love house
# Topic 13: guy good gun horse sheriff gatling movie on ca town gang friend would get wad
# Topic 14: western son gen wad wonder explore film also end clear dram old losing enjoy spar
# Topic 15: film movie on western good act guy ev real wad like would great watch character
# Topic 16: movie act apparently high obviously nothing set particularly going good bland stomach perform men gun
# Topic 17: whos visit however thing hype philosophy decides slow enter present fond decided conversation soulmate inst
# Topic 18: movie film en relationship butch guy killer talk cinematography yes cool battle western prove shock
# Topic 19: worthy conversations takes progress superhero good losing step twist wrong decision look great towards come

# %%
topic_map = nmf.transform(tf)

# %%
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')

# %%
tsne_lda = tsne_model.fit_transform(topic_map)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 274 samples in 0.001s...
# [t-SNE] Computed neighbors for 274 samples in 0.010s...
# [t-SNE] Computed conditional probabilities for sample 274 / 274
# [t-SNE] Mean sigma: 0.063430
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.496037
# [t-SNE] KL divergence after 1000 iterations: 0.491014

# %%
categories = review_urls.keys()

# %%
# so for some reason, the categories vector winds up being 10 shorter than the other things... I think that's because the 
# divison here is doing some rounding (necessary to be able to loop through), so I'm "manually" adding in the extra 10
# I'm really not sure this is the best way to do this, but it seems to work, so... neat?

categories_vector = []

xtra = 0
this_cat_added = 0

for c in categories:
    this_cat_added = 0
    for i in range(int(len(all_reviews) / len(categories))):
        categories_vector.append(c)
        if xtra < 10 and this_cat_added < 1:
            categories_vector.append(c)
            xtra += 1
            this_cat_added = 1

# %%
topics = [np.argmax(t) for t in nmf.transform(tf)]
topics_val = [np.max(t) for t in nmf.transform(tf)]
topics_txt = [nmf_topic_map[t] for t in topics]

# %%
print(len(categories_vector))

print(len(topics))

print(len(topics_txt))

print(len(flat_docs))
# Out:
# 274
# 274
# 274
# 274

# %%
cat_df = pd.DataFrame({
    'x': tsne_lda[:, 0],
    'y': tsne_lda[:, 1],
    'group': categories_vector,
    'topic': topics,
    'topics_txt': topics_txt,
    'text': flat_docs
})

# %%
sn.lmplot(x='x', y='y', fit_reg=False, data=cat_df, hue='group')
plt.gcf().set_size_inches(15, 8)

# %%
sn.heatmap(cat_df.groupby(['topics_txt', 'group']).size().unstack())
