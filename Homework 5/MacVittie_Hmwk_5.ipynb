# %%
from bs4 import BeautifulSoup, SoupStrainer

import nltk
from nltk import word_tokenize, pos_tag, RegexpParser
from nltk.tokenize import sent_tokenize

import re
import requests

# %% [markdown]
# ### MacVittie - Homework 5
# **1)** Compile a list of static links (permalinks) to individual user movie reviews from one particular website. This will be your working dataset for this assignment, as well as for assignments 7 and 8, which together will make up your semester project.
#
# It does not matter if you use a crawler or if you manually collect the links, but you will need at least 100 movie review links. Note that, as of this writing, the robots.txt file of IMDB.com allows the crawling of user reviews.
#
# Each link should be to a web page that has only one user review of only one movie, e.g., the user review permalinks on the IMDB site.
#
# Choose reviews of movies that are all in the same genre, e.g., sci-fi, mystery, romance, superhero, etc.
#
# Make sure your collection includes reviews of several movies in your chosen genre and that it includes a mix of negative and positive reviews.
#
# ```
# Genre is a funny thing, and ill-defined. The films I have selected are from my personal top 10 (and honorable mention),
# as I feel that the films an individual selects for such a list can be deeply telling of a person's personality and
# outlook on life. Near as I can tell, each of these could be reasonably classified as a "drama:" while Megamind perhaps
# leans more towards the comedic end of the spectrum, 3:10 to Yuma almost certainly also a western, the remainder are
# all certainly and deeply within the classification of a drama.
#
# For these films I have chosen, there are 274 reviews. While I have not personally vetted that each has at least a
# positive and negative review, I can be fairly certain - knowing what I know of film, and how the general populace
# responds to such works - that each has at least one of each.
# ```
#
# **2)** Extract noun phrase (NP) chunks from your reviews using the following procedure:
#
# In Python, use BeautifulSoup to grab the main review text from each link.
#
# Next run each review text through a tokenizer, and then try to NP-chunk it with a shallow parser.
#
# You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.
#
# ```
# The reviews have been tokenized and tagged, then placed through a parser. The output seems reasonable.
# ```
#
# **3)** Output all the chunks in a single list for each review, and submit that output for this assignment.
#
# Also submit a brief written summary of what you did (describe your selection of genre, your source of reviews, how many you collected, and by what means).
#
# ```
# As mentioned, I have specifically chosen my top 10 list, which has - somewhat surprisingly - remained unchanged
# for most of this decade, though I have not been able to indulge this hobby as much as I was able to in my 20's as
# of late. I used IMDB as a reference, specifically calling out the initial page for user reviews. I did not crawl
# past the first page for any film, as the resulting 274 reviews seemed sufficient.
# ```

# %%
# first, set up our movie review urls
# movie list is my top 10 + honorable mention: https://www.imdb.com/list/ls050974899/

review_urls = {
    'last_night': 'https://www.imdb.com/title/tt1294688/reviews?ref_=tt_urv',
    'vanilla_sky': 'https://www.imdb.com/title/tt0259711/reviews?ref_=tt_urv',
    'lost_in_translation': 'https://www.imdb.com/title/tt0335266/reviews?ref_=tt_urv',
    'never_let_me_go': 'https://www.imdb.com/title/tt1334260/reviews?ref_=tt_urv',
    'gattaca': 'https://www.imdb.com/title/tt0119177/reviews?ref_=tt_urv',
    'american_beauty': 'https://www.imdb.com/title/tt0169547/reviews?ref_=tt_urv',
    'megamind': 'https://www.imdb.com/title/tt1001526/reviews?ref_=tt_urv',
    'man_from_earth': 'https://www.imdb.com/title/tt0756683/reviews?ref_=tt_urv',
    'another_earth': 'https://www.imdb.com/title/tt1549572/reviews?ref_=tt_urv',
    'timer': 'https://www.imdb.com/title/tt1179794/reviews?ref_=tt_urv',
    '310_to_yuma': 'https://www.imdb.com/title/tt0381849/reviews?ref_=tt_urv',
}

# %%
def get_txt(url):
    return requests.get(url).text


def get_links_from(html):
    tags = BeautifulSoup(html, 'html.parser', parse_only=SoupStrainer('a', href=True))
    urls = [str(tag.attrs['href']) for tag in tags]
    return urls


def get_review_urls(links):
    url_template = 'https://www.imdb.com{}'
    return [url_template.format(link) for link in links]


def link(link):
    if '/review/' in link:
        return True
    return False


def get_links(links):
    links = filter(link, links)
    unique_links = set(links)
    return list(unique_links)


def strain(name, attrs):
    if name == 'div' and dict(attrs).get('class', None) == 'content':
        return True
    return False


def clean_txt(text):
    return re.split('\\n\\n\s+\d+ out of \d+', text)[0]


def get_review_from_url(url):
    html = get_txt(url)
    tags = BeautifulSoup(html, 'html.parser', parse_only=SoupStrainer(strain))
    review = clean_txt(tags.text)
    return review


def get_review_from_site(url):
    reviews = []

    reviews_home_text = get_txt(url)
    all_links = get_links_from(reviews_home_text)
    links = get_links(all_links)

    review_urls = get_review_urls(links)
    for url in review_urls:
        reviews.append(get_review_from_url(url))
    return reviews


def get_reviews_from_all_sites(url_list):
    all_reviews = []
    review_titles = url_list.keys()
    for title in review_titles:
        review_url = review_urls[title]
        all_reviews = all_reviews + get_review_from_site(review_url)
    return all_reviews


def sentences_to_words(sentences):
    return [word_tokenize(s) for s in sentences]


def alphanumerize(words):
    regex_matcher = '^[a-zA-Z0-9]+$'
    return [w for w in words if re.match(regex_matcher, w)]


def lemmatize_word(word):
    stemmer = LancasterStemmer()
    lemma_word = stemmer.stem(word)
    if wordnet.synsets(lemma_word):
        return lemma_word
    else:
        return word    
    
    
def lemmatize_words(words):
    return [lemmatize_word(w) for w in words]


def remove_stops(words):
    return [w for w in words if w not in stop_words]


def preprocess_documents(docs):
    d_format_words = [d.lower().strip() for d in docs]
    docs_of_words = sentences_to_words(d_format_words)
    words_with_chars = [remove_stops(w) for w in docs_of_words]
    content_words = [alphanumerize(c) for c in words_with_chars]
    lemmatized = [lemmatize_words(w) for w in content_words]
    return lemmatized 


def topics_to_map(model, feature_names, no_top_words):
    map = []
    for topic_idx, topic in enumerate(model.components_):
        s = " ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])
        map.append(s)
    return map


def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic {}:".format(topic_idx), end=' ')
        s = " ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]])
        print (s)
        

def pos_tagging(sentence):
    cleaned_review = sentence.lower()
    tokenized_review = word_tokenize(cleaned_review)
    return pos_tag(tokenized_review)


def get_chunking_for_sentence(sentence):
    tagged_sentence = pos_tagging(sentence)

    grammar = "NP: {<DT>?<JJ>*<NN>}"

    cp = nltk.RegexpParser(grammar)
    result = cp.parse(tagged_sentence)
    return result


def get_chunking(review):
    sentences = sent_tokenize(review)
    result = [get_chunking_for_sentence(s) for s in sentences]
    return result        


def get_chunking_for_reviews(reviews):
    return [get_chunking(r) for r in reviews]


def get_noun_phrases_for_review(review):
    main_trees = get_chunking(review)
    subtrees = []
    for m in main_trees:
        for s in m.subtrees():
            if s.label() == 'NP':
                subtrees.append(s)
    
    return subtrees[1:]


def get_noun_phrases_for_reviews(reviews):
    return [get_noun_phrases_for_review(r) for r in reviews]

# %%
all_reviews = get_reviews_from_all_sites(review_urls)

# %%
print(len(all_reviews))
# Out:
# 274

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\GnomeWorks\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
noun_phrases = get_noun_phrases_for_reviews(all_reviews)

# %%
for n in noun_phrases[0:6]:
    for i in range(2):
        print(n[i])
    print()
# Out:
# (NP own/JJ copy.i/NN)
# (NP the/DT storyline/NN)
#
# (NP the/DT romantic/JJ dramas/NN)
# (NP boring/NN)
#
# (NP the/DT rome/NN)
# (NP film/NN)
#
# (NP belarus/NN)
# (NP this/DT season/NN)
#
# (NP i/NN)
# (NP a/DT summary/NN)
#
# (NP catch/NN)
# (NP b-/NN)

# %%
noun_phrases
# Out:
# [[Tree('NP', [('own', 'JJ'), ('copy.i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('storyline', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('sensibility', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('situation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sight', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('pain', 'NN')]),
#   Tree('NP', [('misery', 'NN')]),
#   Tree('NP', [('suffering', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('keira', 'JJ'), ('knightley', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('actor', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('easy-going', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('ex-love', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('fun', 'NN')]),
#   Tree('NP', [('type', 'NN')]),
#   Tree('NP', [('girl', 'NN')]),
#   Tree('NP', [('eva', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('fragile', 'NN')]),
#   Tree('NP', [('unsure', 'JJ'), ('girl', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('quite', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bitch', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('married', 'JJ'), ('man.i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('other', 'JJ'), ('hand', 'NN')]),
#   Tree('NP', [('malignant', 'JJ'), ('cheater', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('victim', 'NN')]),
#   Tree('NP', [('circumstances.i', 'NN')]),
#   Tree('NP', [('guillaume', 'JJ'), ('canet', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('likeliness', 'NN')]),
#   Tree('NP', [('patrick', 'JJ'), ('dempsey', 'NN')]),
#   Tree('NP', [('playing', 'NN')]),
#   Tree('NP', [('feeling', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('persuasively', 'JJ'), ('way', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('name', 'NN')]),
#   Tree('NP', [('mcdreamy.i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('case', 'NN')]),
#   Tree('NP', [('discontent', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('right', 'JJ'), ('end', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('type', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('right', 'JJ'), ('end', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('romantic', 'JJ'), ('dramas', 'NN')]),
#   Tree('NP', [('boring', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('abuse', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('clichés', 'NN')]),
#   Tree('NP', [('intention', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('free', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('surprise', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('marriage', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('faithfulness', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('couple.one', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('screenplay', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('simple', 'JJ'), ('level', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('game', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('couple', 'NN')]),
#   Tree('NP', [('destiny', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rhythm', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('boring', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('runaway', 'JJ'), ('melodrama', 'NN')]),
#   Tree('NP', [('closer', 'NN')]),
#   Tree('NP', [('wide', 'JJ'), ('shut', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('opposite', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('attention', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('expression', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('road', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('paris', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('cathartic', 'JJ'), ('soap', 'NN')]),
#   Tree('NP', [('opera', 'NN')]),
#   Tree('NP', [('melodrama', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('emotional', 'JJ'), ('minimalism', 'NN')]),
#   Tree('NP', [('thematic', 'JJ'), ('clarity.and', 'NN')]),
#   Tree('NP', [('keira', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('amazing', 'JJ'), ('conviction', 'NN')]),
#   Tree('NP', [('aplomb', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('worthington', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('much', 'JJ'), ('wider', 'NN')]),
#   Tree('NP', [('histrionic', 'NN')]),
#   Tree('NP', [('range', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('action', 'NN')]),
#   Tree('NP', [('adventure', 'NN')]),
#   Tree('NP', [('terminator', 'NN')]),
#   Tree('NP', [('salvation', 'NN')]),
#   Tree('NP', [('avatar', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('remake', 'NN')]),
#   Tree('NP', [('clash', 'NN')]),
#   Tree('NP', [('eva', 'NN')]),
#   Tree('NP', [('guillaume', 'JJ'), ('canet', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('show', 'NN')]),
#   Tree('NP', [('fantastic', 'JJ'), ('works.considering', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('romantic', 'JJ'), ('dramas', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('beginning', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('conclusion', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('worthy', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('enthusiastic', 'JJ'), ('recommendation', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('slight', 'JJ'), ('pretension', 'NN')]),
#   Tree('NP', [('film', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('rome', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('festival', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('atmosphere', 'NN')]),
#   Tree('NP', [('new', 'JJ'), ('york', 'NN')]),
#   Tree('NP', [('night', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('soundtrack', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('half', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('hour', 'NN')]),
#   Tree('NP', [('delay', 'NN')]),
#   Tree('NP', [('convincing', 'JJ'), ('interpretation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wife', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('day', 'NN')]),
#   Tree('NP', [('husband', 'NN')]),
#   Tree('NP', [('town', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('female', 'JJ'), ('colleague', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('nature', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('betrayal', 'NN')]),
#   Tree('NP', [('marriage', 'NN')]),
#   Tree('NP', [('sentiment', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('thoughtful', 'JJ'), ('way', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('usual', 'JJ'), ('labelling', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('life', 'NN')]),
#   Tree('NP', [('nobody', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('beautiful', 'NN')]),
#   Tree('NP', [('well-to-do', 'JJ'), ('folk', 'NN')]),
#   Tree('NP', [('fine', 'JJ'), ('wine', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('big', 'JJ'), ('screen', 'NN')]),
#   Tree('NP', [('temptation', 'NN')]),
#   Tree('NP', [('marriage', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('luxury', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wealthy', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('fodder', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('long', 'JJ'), ('conversation', 'NN')])],
#  [Tree('NP', [('belarus', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('season', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('massy', 'NN')]),
#   Tree('NP', [('heart', 'NN')]),
#   Tree('NP', [('wwoow', 'NN')]),
#   Tree('NP', [('head', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('line', 'NN')]),
#   Tree('NP', [('line', 'NN')]),
#   Tree('NP', [('work', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('emotional', 'JJ'), ('level', 'NN')]),
#   Tree('NP', [('further', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('unforgettable', 'JJ'), ('piece', 'NN')]),
#   Tree('NP', [('work.it', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('deepest', 'NN')])],
#  [Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('summary', 'NN')]),
#   Tree('NP', [('everyone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acting', 'NN')]),
#   Tree('NP', [('attention', 'NN')]),
#   Tree('NP', [('emotion', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('intense', 'JJ'), ('desire', 'NN')]),
#   Tree('NP', [('confused', 'JJ'), ('michael', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('excellent', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('opinion', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('honest', 'JJ'), ('look', 'NN')]),
#   Tree('NP', [('desire', 'NN')]),
#   Tree('NP', [('fidelity', 'NN')])],
#  [Tree('NP', [('catch', 'NN')]),
#   Tree('NP', [('b-', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('typical', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('theater', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('emotional', 'JJ'), ('intimate', 'NN')]),
#   Tree('NP', [('infidelity', 'NN')]),
#   Tree('NP', [('infidelity', 'NN')]),
#   Tree('NP', [('infidelity', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('other', 'JJ'), ('person', 'NN')]),
#   Tree('NP', [('keira', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('delight', 'NN')]),
#   Tree('NP', [('thing', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('modern', 'JJ'), ('setup', 'NN')]),
#   Tree('NP', [('%', 'NN')]),
#   Tree('NP', [('period', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('hard', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('actor', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('charisma', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('blue', 'JJ'), ('avatar', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('actor', 'NN')]),
#   Tree('NP', [('stern', 'JJ'), ('face', 'NN')]),
#   Tree('NP', [('guillaume', 'JJ'), ('canet', 'NN')]),
#   Tree('NP', [('aka', 'NN')]),
#   Tree('NP', [('cotilard', 'NN')]),
#   Tree('NP', [('first', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('eva', 'NN')]),
#   Tree('NP', [('sexy.last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('engaging', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('watch', 'NN')]),
#   Tree('NP', [('mode', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('thing', 'NN')])],
#  [Tree('NP', [('rating', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('it.a', 'NN')]),
#   Tree('NP', [('lot', 'NN')]),
#   Tree('NP', [('***', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('emotional', 'JJ'), ('unfaithfulness', 'NN')]),
#   Tree('NP', [('rise', 'NN')]),
#   Tree('NP', [('infidelity', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('only', 'JJ'), ('chance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('massy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('irony', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('real', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('perfect', 'JJ'), ('example', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('sole', 'JJ'), ('object', 'NN')]),
#   Tree('NP', [('attraction', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('jo', 'NN')]),
#   Tree('NP', [('alex', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('theme', 'NN')]),
#   Tree('NP', [('temptation', 'NN')]),
#   Tree('NP', [('massy', 'NN')]),
#   Tree('NP', [('tadjedin', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('hypocrisy', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('notion', 'NN')]),
#   Tree('NP', [('temptation', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('anticipation', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('deed', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('deed', 'NN')]),
#   Tree('NP', [('temptation', 'NN')]),
#   Tree('NP', [('like', 'JJ'), ('foreplay', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('idea', 'NN')]),
#   Tree('NP', [('mind', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('view', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('act', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('truth', 'NN')]),
#   Tree('NP', [('temptation', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('such', 'JJ'), ('position', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('pool', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('challenge', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('strength', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('fantasies.finally', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('alex', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('world', 'NN')]),
#   Tree('NP', [('drama', 'NN')]),
#   Tree('NP', [('air', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('fulfillment', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('urge', 'NN')]),
#   Tree('NP', [('desire', 'NN')]),
#   Tree('NP', [('unbearable', 'JJ'), ('sacrifice', 'NN')]),
#   Tree('NP', [('part', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('way', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('love', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('real', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('single', 'JJ'), ('false', 'JJ'), ('note', 'NN')]),
#   Tree('NP', [('keira', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('fan', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('scenes.the', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('guillame', 'JJ'), ('canet', 'NN')]),
#   Tree('NP', [('–', 'NN')]),
#   Tree('NP', [('behavior', 'NN')]),
#   Tree('NP', [('–', 'NN')]),
#   Tree('NP', [('worthington', 'NN')]),
#   Tree('NP', [('ungrateful', 'JJ'), ('job', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('alex', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('man', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('marrying', 'NN')]),
#   Tree('NP', [('unexciting', 'NN')]),
#   Tree('NP', [('safety', 'NN')]),
#   Tree('NP', [('stability', 'NN')]),
#   Tree('NP', [('neurotic', 'JJ'), ('joanna', 'NN')]),
#   Tree('NP', [('starchy', 'JJ'), ('affair', 'NN')]),
#   Tree('NP', [('exciting', 'JJ'), ('thing', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('poignant', 'NN')]),
#   Tree('NP', [('top', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('different', 'JJ'), ('dance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('night', 'NN')]),
#   Tree('NP', [('michael/laura', 'NN')]),
#   Tree('NP', [('each', 'DT'), ('step', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('minefield', 'NN')]),
#   Tree('NP', [('word', 'NN')]),
#   Tree('NP', [('gesture', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('sign', 'NN')]),
#   Tree('NP', [('readiness', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('plot', 'NN')]),
#   Tree('NP', [('uncomplicated', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('worthington', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('subtle', 'JJ'), ('variety', 'NN')]),
#   Tree('NP', [('party', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('adorable', 'JJ'), ('innocence', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('attractive', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('self', 'NN')]),
#   Tree('NP', [('intimacy', 'NN')]),
#   Tree('NP', [('wife', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('pity', 'NN')]),
#   Tree('NP', [('solid', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('truthfulness', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('urge', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('actor.special', 'JJ'), ('mention', 'NN')]),
#   Tree('NP', [('one', 'NN')]),
#   Tree('NP', [('griffin', 'JJ'), ('dunne', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('scene', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('word', 'NN')]),
#   Tree('NP', [('writing.massy', 'JJ'), ('tadjedin', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('script', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('line', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('chance', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('different', 'JJ'), ('language', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('feeling', 'NN')]),
#   Tree('NP', [('dialog', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('chance', 'NN')]),
#   Tree('NP', [('body', 'NN')]),
#   Tree('NP', [('language', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('next', 'JJ'), ('film', 'NN')])],
#  [Tree('NP', [('unsaid', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('hug', 'NN')]),
#   Tree('NP', [('while', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('surface', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('hug', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('excellent', 'JJ'), ('scriptwriting', 'NN')]),
#   Tree('NP', [('directing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('dialogue', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cinematography', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('cast', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('long', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('straightforwardness', 'NN')]),
#   Tree('NP', [('honesty', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('lovable', 'JJ'), ('oddness', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('tribeca', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('festival', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('aback', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('brilliance', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('simple', 'JJ'), ('concept', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('married', 'JJ'), ('couple', 'NN')]),
#   Tree('NP', [('marital', 'JJ'), ('temptation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('vibe', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('tribeca', 'NN')]),
#   Tree('NP', [('lifestyle', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('young', 'JJ'), ('marriage', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('amazing', 'JJ'), ('job', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('reserved', 'JJ'), ('husband', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('wife', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('crescendo', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('temptation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')])],
#  [Tree('NP', [('thoughtful', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('simple', 'JJ'), ('question', 'NN')]),
#   Tree('NP', [('partner', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('question', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('heart', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('weak', 'JJ'), ('point', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('false', 'JJ'), ('question', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('partner', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('question', 'NN')]),
#   Tree('NP', [('course', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('story', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('poor', 'JJ'), ('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('start', 'NN')]),
#   Tree('NP', [('role', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('boring', 'JJ'), ('spouse', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('person', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('person', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bit', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('dilemma', 'NN')]),
#   Tree('NP', [('man', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('long', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('french', 'JJ'), ('lover', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('romantic', 'JJ'), ('cad', 'NN')]),
#   Tree('NP', [('griffin', 'NN')]),
#   Tree('NP', [('dunne', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('share', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bathroom', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('bit', 'NN')]),
#   Tree('NP', [('thrill', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('relationship', 'NN')]),
#   Tree('NP', [('husband', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('bit', 'NN')]),
#   Tree('NP', [('keira', 'NN')]),
#   Tree('NP', [('selfish', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('weepy', 'JJ'), ('parting', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('idea', 'NN')]),
#   Tree('NP', [('idea', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('reality', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('guy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wine', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('taxi.what', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('other', 'JJ'), ('side', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('wife', 'NN')]),
#   Tree('NP', [('projection', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('guilt', 'NN')]),
#   Tree('NP', [('secret', 'NN')]),
#   Tree('NP', [('behavior', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('temptress', 'NN')]),
#   Tree('NP', [('hey', 'NN')]),
#   Tree('NP', [('wife', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('moment', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('boring', 'NN')]),
#   Tree('NP', [('loving', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('get', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('pool', 'NN')]),
#   Tree('NP', [('sure', 'NN')]),
#   Tree('NP', [('sex', 'NN')]),
#   Tree('NP', [('room', 'NN')]),
#   Tree('NP', [('slept', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('whole', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('wife', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('passionless', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('complicated', 'JJ'), ('question', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('performance', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('wife', 'NN')]),
#   Tree('NP', [('alternate', 'NN')]),
#   Tree('NP', [('affair', 'NN')]),
#   Tree('NP', [('keira', 'NN')]),
#   Tree('NP', [('guillaume', 'NN')]),
#   Tree('NP', [('sam', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('boring', 'JJ'), ('husband', 'NN')]),
#   Tree('NP', [('body', 'NN')]),
#   Tree('NP', [('language', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('blockbuster', 'NN')]),
#   Tree('NP', [('action', 'NN')]),
#   Tree('NP', [('star', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('storm', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('role', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('sense', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('music', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('pacing', 'NN')]),
#   Tree('NP', [('perfect', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('ten', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('point', 'NN')]),
#   Tree('NP', [('none', 'NN')]),
#   Tree('NP', [('i', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('drama', 'NN')]),
#   Tree('NP', [('pure', 'NN')]),
#   Tree('NP', [('state', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('couple', 'NN')]),
#   Tree('NP', [('marriage', 'NN')]),
#   Tree('NP', [('fundamental', 'JJ'), ('importance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('couple', 'NN')]),
#   Tree('NP', [('loyalty', 'NN')]),
#   Tree('NP', [('trust', 'NN')]),
#   Tree('NP', [('lust', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('reed', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wife', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('writer', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('works', 'JJ'), ('freelance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('home', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('husband', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('construction', 'NN')]),
#   Tree('NP', [('contract', 'NN')]),
#   Tree('NP', [('company', 'NN')]),
#   Tree('NP', [('town', 'NN')]),
#   Tree('NP', [('business', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('decent', 'JJ'), ('apartment', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('city', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('other', 'JJ'), ('couple', 'NN')]),
#   Tree('NP', [('moment', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('office', 'NN')]),
#   Tree('NP', [('party', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('husband', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lady', 'NN')]),
#   Tree('NP', [('friend', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mild', 'JJ'), ('argument', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('town', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('business', 'NN')]),
#   Tree('NP', [('trip', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('team', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('amusement', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('day', 'NN')]),
#   Tree('NP', [('x', 'JJ'), ('boyfriend', 'NN')]),
#   Tree('NP', [('dinner', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('night', 'NN')]),
#   Tree('NP', [('past', 'JJ'), ('love', 'NN')]),
#   Tree('NP', [('feeling', 'JJ'), ('insecure', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('twist', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('viewer', 'NN')]),
#   Tree('NP', [('ample', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('night', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('admire', 'JJ'), ('everyone', 'NN')]),
#   Tree('NP', [('keira', 'NN')]),
#   Tree('NP', [('attitude', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('confused', 'JJ'), ('husband', 'NN')]),
#   Tree('NP', [('skill', 'NN')]),
#   Tree('NP', [('marriage', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('trust', 'NN')]),
#   Tree('NP', [('fragile', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('guilt', 'NN')]),
#   Tree('NP', [('all.read', 'NN')]),
#   Tree('NP', [('flickshout.blogspot.com', 'NN')])],
#  [Tree('NP', [('an', 'DT'), ('insightful', 'JJ'), ('look', 'NN')]),
#   Tree('NP', [('infidelity', 'NN')]),
#   Tree('NP', [('type', 'NN')]),
#   Tree('NP', [('infidelity', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('heart', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('husband', 'NN')]),
#   Tree('NP', [('worthington', 'NN')]),
#   Tree('NP', [('affair', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('meeting', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('canet.the', 'JJ'), ('knightley/canet', 'NN')]),
#   Tree('NP', [('storyline', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('easy', 'JJ'), ('flow', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('maturing', 'JJ'), ('actress', 'NN')]),
#   Tree('NP', [('such', 'JJ'), ('charm', 'NN')]),
#   Tree('NP', [('screen', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('sense', 'NN')]),
#   Tree('NP', [('misguided', 'JJ'), ('loyalty', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('moment', 'NN')]),
#   Tree('NP', [('her.mendes/worthington', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bit', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('let', 'NN')]),
#   Tree('NP', [('chemistry', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('main', 'JJ'), ('issue', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('actress', 'NN')]),
#   Tree('NP', [('wooden', 'NN')]),
#   Tree('NP', [('monotone', 'NN')]),
#   Tree('NP', [('role', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('past', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('less', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('married', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('line', 'NN')]),
#   Tree('NP', [('delivery', 'NN')]),
#   Tree('NP', [('feeling', 'JJ'), ('unmoved.knightley/canet', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('view', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('plane', 'NN')]),
#   Tree('NP', [('home', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('window', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('montage', 'NN')]),
#   Tree('NP', [('nothing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('storyline', 'NN')]),
#   Tree('NP', [('background', 'NN')]),
#   Tree('NP', [('pivotal', 'JJ'), ('construction', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('truth', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('i', 'JJ'), ('doubt', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('mundane', 'NN')]),
#   Tree('NP', [('thought', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('night', 'NN')])],
#  [Tree('NP', [('line', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('while', 'NN')]),
#   Tree('NP', [('to-date', 'NN')]),
#   Tree('NP', [('mind', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('piece', 'NN')]),
#   Tree('NP', [('intimate', 'NN')]),
#   Tree('NP', [('exquisite', 'JJ'), ('cinema', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('opposite', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('epic', 'NN')]),
#   Tree('NP', [('montage', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('opening', 'NN')]),
#   Tree('NP', [('scene', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('stage', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('brief', 'JJ'), ('introduction', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('young', 'JJ'), ('new', 'JJ'), ('york', 'NN')]),
#   Tree('NP', [('couple', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('evening', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('scene', 'NN')]),
#   Tree('NP', [('forth', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('party', 'NN')]),
#   Tree('NP', [('scene', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('pensive', 'NN')]),
#   Tree('NP', [('reflective', 'JJ'), ('face', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cab', 'NN')]),
#   Tree('NP', [('way', 'NN')]),
#   Tree('NP', [('home', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('party', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('evening', 'NN')]),
#   Tree('NP', [('intimate', 'JJ'), ('conversion', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('attractive', 'JJ'), ('colleague', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('existence', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('business', 'NN')]),
#   Tree('NP', [('trip', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('4-year', 'JJ'), ('marriage', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('stress', 'JJ'), ('test', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('trip', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('next', 'JJ'), ('day', 'NN')]),
#   Tree('NP', [('night', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('guillaume', 'JJ'), ('canet', 'NN')]),
#   Tree('NP', [('on-and-off', 'NN')]),
#   Tree('NP', [('paris', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('book', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('book', 'NN')]),
#   Tree('NP', [('rest', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('development', 'NN')]),
#   Tree('NP', [('new', 'JJ'), ('york', 'NN')]),
#   Tree('NP', [('philadelphia', 'NN')]),
#   Tree('NP', [('forth', 'NN')]),
#   Tree('NP', [('voice-over', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('point', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('pedantic', 'JJ'), ('account', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('enjoyment', 'NN')]),
#   Tree('NP', [('philadelphia', 'NN')]),
#   Tree('NP', [('torrid', 'JJ'), ('love', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('scene', 'NN')]),
#   Tree('NP', [('seductive', 'JJ'), ('charm', 'NN')]),
#   Tree('NP', [('ooze', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('languid', 'JJ'), ('dialogue', 'NN')]),
#   Tree('NP', [('heartbreaking', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('new', 'JJ'), ('york', 'NN')]),
#   Tree('NP', [('bittersweet', 'NN')]),
#   Tree('NP', [('layer', 'NN')]),
#   Tree('NP', [('layer', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('depth', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('bed', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('ultra-literal', 'JJ'), ('sense', 'NN')]),
#   Tree('NP', [('bill', 'NN')]),
#   Tree('NP', [('murray', 'NN')]),
#   Tree('NP', [('scarlett', 'NN')]),
#   Tree('NP', [('johansson', 'NN')]),
#   Tree('NP', [('translation', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('review', 'NN')]),
#   Tree('NP', [('evening', 'NN')]),
#   Tree('NP', [('night', 'NN')]),
#   Tree('NP', [('sunrise', 'NN')]),
#   Tree('NP', [('difference', 'NN')]),
#   Tree('NP', [('jesse', 'NN')]),
#   Tree('NP', [('celine', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('sunset', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('night', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('pleasure', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('role', 'NN')]),
#   Tree('NP', [('worthington', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('assortment', 'NN')]),
#   Tree('NP', [('earth', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('nuclear', 'JJ'), ('holocaust', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('exotic', 'JJ'), ('planet', 'NN')]),
#   Tree('NP', [('avatar', 'NN')]),
#   Tree('NP', [('mythological', 'JJ'), ('greece', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('troubled', 'JJ'), ('marriage', 'NN')]),
#   Tree('NP', [('facing', 'JJ'), ('temptation', 'NN')]),
#   Tree('NP', [('canet', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('heart-throb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('undisputed', 'JJ'), ('successor', 'NN')]),
#   Tree('NP', [('grant', 'NN')]),
#   Tree('NP', [('charm', 'NN')]),
#   Tree('NP', [('comedy.the', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('variety', 'NN')]),
#   Tree('NP', [('sheer', 'JJ'), ('fun', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('dilemmas', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('temptation', 'NN')]),
#   Tree('NP', [('infidelity', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('modern', 'JJ'), ('middle-class', 'NN')]),
#   Tree('NP', [('setting', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wife', 'NN')]),
#   Tree('NP', [('keira', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('temptress', 'NN')]),
#   Tree('NP', [('eva', 'NN')]),
#   Tree('NP', [('correspond', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('sense', 'NN')]),
#   Tree('NP', [('complement', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('husband', 'NN')]),
#   Tree('NP', [('plain', 'NN')]),
#   Tree('NP', [('temptation', 'NN')]),
#   Tree('NP', [('guillaume', 'JJ'), ('cannet', 'NN')]),
#   Tree('NP', [('flamboyant', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('worthington', 'NN')]),
#   Tree('NP', [('temptation', 'NN')]),
#   Tree('NP', [('cannet.it', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('modern', 'JJ'), ('morality', 'NN')]),
#   Tree('NP', [('tale', 'NN')]),
#   Tree('NP', [('remorse', 'NN')]),
#   Tree('NP', [('return', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('family', 'NN')]),
#   Tree('NP', [('hearth', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('sense', 'NN')]),
#   Tree('NP', [('conservative', 'JJ'), ('rendering', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('topic', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('depiction', 'NN')]),
#   Tree('NP', [('new', 'JJ'), ('york', 'NN')]),
#   Tree('NP', [('philadelphia', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('general', 'JJ'), ('view', 'NN')]),
#   Tree('NP', [('detail', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('sense', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('average', 'JJ'), ('portrayal', 'NN')]),
#   Tree('NP', [('big', 'JJ'), ('metropolitan', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('order', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('realist', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('couple', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('model', 'NN')]),
#   Tree('NP', [('bohemian', 'JJ'), ('lifestyle', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('momentary', 'JJ'), ('infidelity', 'NN')]),
#   Tree('NP', [('middle-class', 'NN')]),
#   Tree('NP', [('morality', 'NN')]),
#   Tree('NP', [('alfred', 'JJ'), ('doolitle', 'NN')]),
#   Tree('NP', [('fair', 'JJ'), ('lady', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('attention', 'NN')]),
#   Tree('NP', [('detail', 'NN')]),
#   Tree('NP', [('every-day', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('people.recommended', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('imagination', 'NN')]),
#   Tree('NP', [('movie', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('teenager', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('need', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('question', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('sexual', 'JJ'), ('betrayal', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('romantic', 'JJ'), ('betrayal', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('sex', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('private', 'JJ'), ('prince', 'NN')]),
#   Tree('NP', [('charming', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('thing', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('show', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('ensemble', 'JJ'), ("c'est", 'NN')]),
#   Tree('NP', [('tout', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('sam', 'NN')]),
#   Tree('NP', [('plastic', 'NN')]),
#   Tree('NP', [('keira', 'NN')]),
#   Tree('NP', [('uncertainty', 'NN')]),
#   Tree('NP', [('anger', 'NN')]),
#   Tree('NP', [('excitement', 'NN')]),
#   Tree('NP', [('eva', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('oscar', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('roll', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('script', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('photography', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('intimate', 'NN')]),
#   Tree('NP', [('atmosphere', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('need', 'NN')]),
#   Tree('NP', [('these', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('hard', 'JJ'), ('work', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')])],
#  [Tree('NP', [('tale', 'NN')]),
#   Tree('NP', [('fascinating', 'NN')]),
#   Tree('NP', [('evening', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('initial', 'JJ'), ('directing', 'NN')]),
#   Tree('NP', [('iranian-american', 'JJ'), ('writer', 'NN')]),
#   Tree('NP', [('massy', 'NN')]),
#   Tree('NP', [('tadjedin', 'NN')]),
#   Tree('NP', [('jacket', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('script', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('reed', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('beautiful', 'JJ'), ('young', 'JJ'), ('writer', 'NN')]),
#   Tree('NP', [('commercial', 'JJ'), ('real', 'JJ'), ('estate', 'NN')]),
#   Tree('NP', [('developer', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('reed', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('happy', 'JJ'), ('marriage', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('struggle', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('company', 'NN')]),
#   Tree('NP', [('party', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('soft', 'JJ'), ('spoken', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('attention', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sensuous', 'JJ'), ('laura', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('act', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('suspicious', 'JJ'), ('behavior', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('part', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('seed', 'NN')]),
#   Tree('NP', [('doubt', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('business', 'NN')]),
#   Tree('NP', [('trip', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('next', 'JJ'), ('morning', 'NN')]),
#   Tree('NP', [('anson', 'JJ'), ('mount', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('friction', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('reassurance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('next', 'JJ'), ('day', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('coffee', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('old', 'JJ'), ('flame', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('alex', 'JJ'), ('mann', 'NN')]),
#   Tree('NP', [('guillaume', 'JJ'), ('cadet', 'NN')]),
#   Tree('NP', [('chemistry', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('evening', 'NN')]),
#   Tree('NP', [('joanna', 'JJ'), ('dine', 'NN')]),
#   Tree('NP', [('alex', 'NN')]),
#   Tree('NP', [('publisher', 'NN')]),
#   Tree('NP', [('truman', 'NN')]),
#   Tree('NP', [('griffin', 'JJ'), ('dunne', 'NN')]),
#   Tree('NP', [('truman', 'NN')]),
#   Tree('NP', [('past', 'JJ'), ('affair', 'NN')]),
#   Tree('NP', [('joanna', 'NN')]),
#   Tree('NP', [('alex', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('relationship', 'NN')]),
#   Tree('NP', [('paris', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('couple', 'NN')]),
#   Tree('NP', [('apartment', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('evening', 'NN')]),
#   Tree('NP', [('laura', 'JJ'), ('enter', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('seduction', 'NN')]),
#   Tree('NP', [('dance', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('attempt', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('web', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('manner', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('aftermath', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('brilliance', 'NN')]),
#   Tree('NP', [('massy', 'NN')]),
#   Tree('NP', [('writing', 'NN')]),
#   Tree('NP', [('direction', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('much', 'JJ'), ('form', 'NN')]),
#   Tree('NP', [('vantage', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('quartet', 'NN')]),
#   Tree('NP', [('knightley', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('fine', 'JJ'), ('actress', 'NN')]),
#   Tree('NP', [('sam', 'JJ'), ('worthington', 'NN')]),
#   Tree('NP', [('stodgy', 'NN')]),
#   Tree('NP', [('shell', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('fidelity', 'NN')]),
#   Tree('NP', [('lust', 'NN')]),
#   Tree('NP', [('laura', 'NN')]),
#   Tree('NP', [('dimension', 'NN')]),
#   Tree('NP', [('guillaume', 'JJ'), ('cadet', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('alex', 'NN')]),
#   Tree('NP', [('true', 'JJ'), ('star', 'NN')]),
#   Tree('NP', [('power', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('method', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('development', 'NN')]),
#   Tree('NP', [('night', 'NN')]),
#   Tree('NP', [('forth', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('progress', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('dance', 'NN')]),
#   Tree('NP', [('seduction', 'NN')]),
#   Tree('NP', [('vs', 'NN')]),
#   Tree('NP', [('fidelity', 'NN')]),
#   Tree('NP', [('person', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('introduction', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('writer/director', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('successful', 'JJ'), ('career', 'NN')]),
#   Tree('NP', [('grady', 'JJ'), ('harp', 'NN')])],
#  [Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('lukewarm', 'JJ'), ('user', 'NN')]),
#   Tree('NP', [('rating', 'NN')]),
#   Tree('NP', [('imdb', 'NN')]),
#   Tree('NP', [('point', 'NN')]),
#   Tree('NP', [('view', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('depiction', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('faith', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('momentum', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('only', 'JJ'), ('criticism', 'NN')]),
#   Tree('NP', [('worthington', 'NN')]),
#   Tree('NP', [('wooden', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('brilliant', 'JJ'), ('final', 'JJ'), ('scene', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('rating', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('long', 'JJ'), ('distance', 'NN')]),
#   Tree('NP', [('relationship', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('hence', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('moved', 'JJ'), ('i', 'NN')]),
#   Tree('NP', [('guess..', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('unforgettable', 'JJ'), ('mark', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
# ...
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('problem', 'NN')]),
#   Tree('NP', [('belief', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('ride', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('western', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('theater', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('box', 'NN')]),
#   Tree('NP', [('office', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('acting', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('development', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wider', 'NN')]),
#   Tree('NP', [('framework', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('hero', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('ample', 'JJ'), ('fuel', 'NN')]),
#   Tree('NP', [('further', 'JJ'), ('discussion', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('plot', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('nice', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('entire', 'JJ'), ('cast', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('direction', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('pace', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('glance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acting', 'NN')]),
#   Tree('NP', [('action', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('high', 'JJ'), ('noon', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('fertile', 'JJ'), ('ground', 'NN')]),
#   Tree('NP', [('man', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('gray', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('volume', 'NN')]),
#   Tree('NP', [('impossible', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('posse', 'NN')]),
#   Tree('NP', [('russel', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('ridiculous', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('point', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('home', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('old', 'JJ'), ('west', 'NN')]),
#   Tree('NP', [('nothing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('reward', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('hostile', 'JJ'), ('indian', 'JJ'), ('territory', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('train', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('mention', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('trial', 'NN')]),
#   Tree('NP', [('idiocy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('excellent', 'NN')]),
#   Tree('NP', [('%', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('i', 'JJ'), ('cant', 'JJ'), ('understand', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('night', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('preview', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('lead', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('toronto', 'JJ'), ('international', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('festival', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('big', 'JJ'), ('western', 'JJ'), ('fan', 'NN')]),
#   Tree('NP', [('shane', 'NN')]),
#   Tree('NP', [('high', 'JJ'), ('noon', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wild', 'JJ'), ('bunch', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('line', 'NN')]),
#   Tree('NP', [('last', 'JJ'), ('directorial', 'JJ'), ('effort', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('hype', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('action', 'NN')]),
#   Tree('NP', [('tension', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('plot', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acting', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('doubt', 'NN')]),
#   Tree('NP', [('ben', 'NN')]),
#   Tree('NP', [('foster', 'NN')]),
#   Tree('NP', [('affected', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('russell', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('loyal', 'NN')]),
#   Tree('NP', [('psychopathic', 'JJ'), ('sidekick', 'NN')]),
#   Tree('NP', [('johnny', 'NN')]),
#   Tree('NP', [('depp', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('pirate', 'NN')]),
#   Tree('NP', [('taste', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('number', 'NN')]),
#   Tree('NP', [('performances.russell', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('amoral', 'JJ'), ('outlaw', 'NN')]),
#   Tree('NP', [('ben', 'NN')]),
#   Tree('NP', [('wade', 'NN')]),
#   Tree('NP', [('role', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('beleaguered', 'JJ'), ('rancher', 'NN')]),
#   Tree('NP', [('civil', 'JJ'), ('war', 'NN')]),
#   Tree('NP', [('veteran', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('right', 'JJ'), ('mix', 'NN')]),
#   Tree('NP', [('pathos', 'NN')]),
#   Tree('NP', [('dignity', 'NN')]),
#   Tree('NP', [('iy', 'NN')]),
#   Tree('NP', [('peter', 'JJ'), ('fonda', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('role', 'NN')]),
#   Tree('NP', [('genuine', 'JJ'), ('talent', 'NN')]),
#   Tree('NP', [('view', 'NN')]),
#   Tree('NP', [('logan', 'JJ'), ('lerman', 'NN')]),
#   Tree('NP', [('way', 'NN')]),
#   Tree('NP', [('teenage', 'NN')]),
#   Tree('NP', [('son', 'NN')]),
#   Tree('NP', [('age', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('course', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('father', 'NN')]),
#   Tree('NP', [('drudge', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('failure', 'NN')]),
#   Tree('NP', [('father', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('hero', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('expanse', 'NN')]),
#   Tree('NP', [('majesty', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('american', 'JJ'), ('west', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('traditional', 'JJ'), ('western', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('remake', 'NN')]),
#   Tree('NP', [('anymore', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('era', 'NN')]),
#   Tree('NP', [('dysfunctional', 'JJ'), ('modern', 'JJ'), ('life', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('new', 'JJ'), ('york', 'NN')]),
#   Tree('NP', [('amazing', 'NN')]),
#   Tree('NP', [('bale', 'NN')]),
#   Tree('NP', [('lead', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('heartless', 'NN')]),
#   Tree('NP', [('killer', 'NN')]),
#   Tree('NP', [('course', 'NN')]),
#   Tree('NP', [('ben', 'JJ'), ('foster', 'NN')]),
#   Tree('NP', [('ben', 'NN')]),
#   Tree('NP', [('foster', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('bigtime', 'NN')]),
#   Tree('NP', [('cause', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('ben', 'NN')]),
#   Tree('NP', [('foster', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('story-wise', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('opposite', 'JJ'), ('butch', 'NN')]),
#   Tree('NP', [('cassidy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sundance', 'NN')]),
#   Tree('NP', [('kid', 'NN')]),
#   Tree('NP', [('order', 'NN')]),
#   Tree('NP', [('train', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('awesome', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('na', 'JJ'), ('watch', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('last', 'JJ'), ('battle', 'NN')])],
#  [Tree('NP', [('favour', 'JJ'), ('amongst', 'NN')]),
#   Tree('NP', [('commercial', 'JJ'), ('success', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('wild', 'JJ'), ('bunch', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('genre', 'NN')]),
#   Tree('NP', [('distinction', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('good', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('reason', 'NN')]),
#   Tree('NP', [('limited', 'JJ'), ('concept', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('uneasy', 'JJ'), ('mixture', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('fugitive', 'JJ'), ('ben', 'NN')]),
#   Tree('NP', [('wadee', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('posse', 'NN')]),
#   Tree('NP', [('arizona', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rail', 'NN')]),
#   Tree('NP', [('station', 'NN')]),
#   Tree('NP', [('yuma', 'NN')]),
#   Tree('NP', [('trial', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('federal', 'JJ'), ('court', 'NN')]),
#   Tree('NP', [('wade', 'NN')]),
#   Tree('NP', [('gang', 'NN')]),
#   Tree('NP', [('charlie', 'NN')]),
#   Tree('NP', [('prince', 'NN')]),
#   Tree('NP', [('wade', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rail', 'NN')]),
#   Tree('NP', [('station', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('problem', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('cake', 'NN')]),
#   Tree('NP', [('eat', 'NN')]),
#   Tree('NP', [('russell', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('ben', 'NN')]),
#   Tree('NP', [('wade', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('leader', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('gang', 'NN')]),
#   Tree('NP', [('outlaws', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('first', 'JJ'), ('glimpse', 'NN')]),
#   Tree('NP', [('wade', 'NN')]),
#   Tree('NP', [('gang', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('coach', 'NN')]),
#   Tree('NP', [('gold', 'NN')]),
#   Tree('NP', [('escort', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('empathy', 'NN')]),
#   Tree('NP', [('wade', 'NN')]),
#   Tree('NP', [('dan', 'NN')]),
#   Tree('NP', [('hand', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('armed', 'JJ'), ('robbery', 'NN')]),
#   Tree('NP', [('innocent', 'JJ'), ('passer', 'NN')]),
#   Tree('NP', [('bys', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('warped', 'JJ'), ('view', 'NN')]),
#   Tree('NP', [('morality', 'NN')]),
#   Tree('NP', [('prince', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('villain', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('piece', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('code', 'NN')]),
#   Tree('NP', [('honour', 'NN')]),
#   Tree('NP', [('gang', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('cost', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rescue', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('prnce', 'NN')]),
#   Tree('NP', [('mentor', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('final', 'JJ'), ('climatic', 'JJ'), ('ridiculous', 'JJ'), ('shoot', 'NN')]),
#   Tree('NP', [('place', 'NN')]),
#   Tree('NP', [('narrative', 'JJ'), ('wise', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sort', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('sam', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('ethos', 'NN')]),
#   Tree('NP', [('new', 'JJ'), ('hollywood', 'NN')]),
#   Tree('NP', [('radical', 'JJ'), ('view', 'NN')]),
#   Tree('NP', [('morality', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('tired', 'JJ'), ('genre', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('screen', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('honest', 'NN')]),
#   Tree('NP', [('rancher', 'NN')]),
#   Tree('NP', [('part', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('doomed', 'JJ'), ('group', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('enigmatic', 'JJ'), ('bandit', 'NN')]),
#   Tree('NP', [('killer', 'NN')]),
#   Tree('NP', [('ben', 'NN')]),
#   Tree('NP', [('wade', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('train', 'NN')]),
#   Tree('NP', [('bisbee', 'NN')]),
#   Tree('NP', [('arizona', 'NN')]),
#   Tree('NP', [('yuma', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('trial', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('old', 'JJ'), ('civil', 'JJ'), ('war', 'NN')]),
#   Tree('NP', [('injury', 'NN')]),
#   Tree('NP', [('farm', 'NN')]),
#   Tree('NP', [('family', 'NN')]),
#   Tree('NP', [('wade', 'NN')]),
#   Tree('NP', [('ruthless', 'NN')]),
#   Tree('NP', [('gang', 'NN')]),
#   Tree('NP', [('teenage', 'NN')]),
#   Tree('NP', [('son', 'NN')]),
#   Tree('NP', [('logan', 'JJ'), ('lerman', 'NN')]),
#   Tree('NP', [('disappointment', 'NN')]),
#   Tree('NP', [('impoverished', 'JJ'), ('father', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('charismatic', 'JJ'), ('criminal', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('quantity', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('perilous', 'JJ'), ('trip', 'NN')]),
#   Tree('NP', [('city', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('real', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('son', 'NN')]),
#   Tree('NP', [('respect', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('unknown', 'JJ'), ('destiny', 'NN')]),
#   Tree('NP', [('son', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('unforgettable', 'JJ'), ('picture', 'NN')]),
#   Tree('NP', [('poignant', 'NN')]),
#   Tree('NP', [('wade\x97leader', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('murderous', 'JJ'), ('band', 'NN')]),
#   Tree('NP', [('robbers\x97had', 'JJ'), ('great', 'JJ'), ('respect', 'NN')]),
#   Tree('NP', [('dan', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('understanding', 'NN')]),
#   Tree('NP', [('appreciation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('hotel', 'NN')]),
#   Tree('NP', [('room', 'NN')]),
#   Tree('NP', [('relation', 'NN')]),
#   Tree('NP', [('family', 'NN')]),
#   Tree('NP', [('dignity', 'NN')]),
#   Tree('NP', [('virtue', 'NN')]),
#   Tree('NP', [('admirable', 'JJ'), ('integrity', 'NN')]),
#   Tree('NP', [('dan', 'NN')]),
#   Tree('NP', [('conscience', 'NN')]),
#   Tree('NP', [('dan', 'NN')]),
#   Tree('NP', [('favorite', 'JJ'), ('part', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('interpretation', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('gifted', 'JJ'), ('cold-blooded', 'JJ'), ('smooth-talking', 'JJ'), ('bad', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('bale', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('struggling', 'NN')]),
#   Tree('NP', [('rancher', 'NN')]),
#   Tree('NP', [('misunderstood', 'NN')]),
#   Tree('NP', [('whole', 'JJ'), ('family', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('remake', 'NN')]),
#   Tree('NP', [('delmer', 'NN')]),
#   Tree('NP', [('picture', 'NN')]),
#   Tree('NP', [('realistic', 'JJ'), ('violence', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('action', 'NN')]),
#   Tree('NP', [('photography', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('inevitable', 'JJ'), ('final', 'JJ'), ('shoot-out', 'NN')])],
#  [Tree('NP', [('bc', 'NN')]),
#   Tree('NP', [('hit-man', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('biscuit', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('piece', 'NN')]),
#   Tree('NP', [('trash', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('thinking', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('huge', 'JJ'), ('nosedive', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('hell', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('christian', 'JJ'), ('bale', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('bit', 'NN')]),
#   Tree('NP', [('shaky', 'JJ'), ('start', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('guy', 'NN')]),
#   Tree('NP', [('shot', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('stomach', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('miraculous', 'JJ'), ('recovery', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('unknown', 'JJ'), ('reason', 'NN')]),
#   Tree('NP', [('crowe', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bad', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('whole', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('money', 'NN')])]]
